# %% [markdown]
# <a href="https://colab.research.google.com/github/hussainturii/TTS/blob/main/clone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check GPU availability
# !nvidia-smi

# Clone the repository
# !git clone https://github.com/SWivid/F5-TTS.git
# %cd F5-TTS
# Out:
# Tue Oct  7 21:11:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Cloning into 'F5-TTS'...
# remote: Enumerating objects: 3580, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 3580 (delta 4), reused 4 (delta 4), pack-reused 3569 (from 2)
# Receiving objects: 100% (3580/3580), 2.24 MiB | 31.48 MiB/s, done.
# Resolving deltas: 100% (2192/2192), done.
# /content/F5-TTS

# %%
# Install required packages
# !pip install -e .
# !pip install cached_path
# !pip install librosa soundfile torchaudio
# !pip install gradio
# Out:
# Obtaining file:///content/F5-TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.33.0 in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (1.10.1)
# Collecting bitsandbytes>0.37.0 (from f5-tts==1.1.9)
#   Downloading bitsandbytes-0.48.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting cached_path (from f5-tts==1.1.9)
#   Downloading cached_path-1.8.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (8.3.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (4.0.0)
# Collecting ema_pytorch>=0.5.2 (from f5-tts==1.1.9)
#   Downloading ema_pytorch-0.7.7-py3-none-any.whl.metadata (689 bytes)
# Requirement already satisfied: gradio>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (5.47.2)
# Collecting hydra-core>=1.3.0 (from f5-tts==1.1.9)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (0.42.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (0.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (3.10.0)
# Collecting pydantic<=2.10.6 (from f5-tts==1.1.9)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (0.25.1)
# Collecting pypinyin (from f5-tts==1.1.9)
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (0.6.2)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (0.13.1)
# Collecting tomli (from f5-tts==1.1.9)
#   Downloading tomli-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (2.8.0+cu126)
# Requirement already satisfied: torchaudio>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (2.8.0+cu126)
# Collecting torchdiffeq (from f5-tts==1.1.9)
#   Downloading torchdiffeq-0.2.5-py3-none-any.whl.metadata (440 bytes)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (4.56.2)
# Collecting transformers_stream_generator (from f5-tts==1.1.9)
#   Downloading transformers-stream-generator-0.0.5.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting unidecode (from f5-tts==1.1.9)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting vocos (from f5-tts==1.1.9)
#   Downloading vocos-0.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from f5-tts==1.1.9) (0.22.1)
# Collecting x_transformers>=1.31.14 (from f5-tts==1.1.9)
#   Downloading x_transformers-2.8.2-py3-none-any.whl.metadata (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->f5-tts==1.1.9) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->f5-tts==1.1.9) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->f5-tts==1.1.9) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->f5-tts==1.1.9) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33.0->f5-tts==1.1.9) (0.35.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.118.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.6.1)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (3.11.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (11.3.0)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.13.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.19.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio>=5.0.0->f5-tts==1.1.9) (0.37.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio>=5.0.0->f5-tts==1.1.9) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio>=5.0.0->f5-tts==1.1.9) (15.0.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.0->f5-tts==1.1.9) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.0->f5-tts==1.1.9) (4.9.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.10.6->f5-tts==1.1.9) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic<=2.10.6->f5-tts==1.1.9)
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->f5-tts==1.1.9) (3.4.0)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from x_transformers>=1.31.14->f5-tts==1.1.9) (0.8.1)
# Collecting einx>=0.3.0 (from x_transformers>=1.31.14->f5-tts==1.1.9)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting loguru (from x_transformers>=1.31.14->f5-tts==1.1.9)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from cached_path->f5-tts==1.1.9) (2.32.4)
# Requirement already satisfied: rich<14.0,>=12.1 in /usr/local/lib/python3.12/dist-packages (from cached_path->f5-tts==1.1.9) (13.9.4)
# Collecting boto3<2.0,>=1.0 (from cached_path->f5-tts==1.1.9)
#   Downloading boto3-1.40.47-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from cached_path->f5-tts==1.1.9) (2.19.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->f5-tts==1.1.9) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->f5-tts==1.1.9) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->f5-tts==1.1.9) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->f5-tts==1.1.9) (0.70.16)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->f5-tts==1.1.9) (1.1.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->f5-tts==1.1.9) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->f5-tts==1.1.9) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->f5-tts==1.1.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->f5-tts==1.1.9) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->f5-tts==1.1.9) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->f5-tts==1.1.9) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->f5-tts==1.1.9) (2.9.0.post0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->f5-tts==1.1.9) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->f5-tts==1.1.9) (0.22.1)
# Collecting encodec==0.1.1 (from vocos->f5-tts==1.1.9)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->f5-tts==1.1.9) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->f5-tts==1.1.9) (4.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->f5-tts==1.1.9) (5.29.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->f5-tts==1.1.9) (2.39.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio>=5.0.0->f5-tts==1.1.9) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio>=5.0.0->f5-tts==1.1.9) (1.3.1)
# Collecting botocore<1.41.0,>=1.40.47 (from boto3<2.0,>=1.0->cached_path->f5-tts==1.1.9)
#   Downloading botocore-1.40.47-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.0->cached_path->f5-tts==1.1.9)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3<2.0,>=1.0->cached_path->f5-tts==1.1.9)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->f5-tts==1.1.9) (2.23)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->x_transformers>=1.31.14->f5-tts==1.1.9) (2.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (3.12.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->f5-tts==1.1.9) (4.0.12)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (1.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio>=5.0.0->f5-tts==1.1.9) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio>=5.0.0->f5-tts==1.1.9) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio>=5.0.0->f5-tts==1.1.9) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.33.0->f5-tts==1.1.9) (1.1.10)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->f5-tts==1.1.9) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->f5-tts==1.1.9) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->f5-tts==1.1.9) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->f5-tts==1.1.9) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->cached_path->f5-tts==1.1.9) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->cached_path->f5-tts==1.1.9) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=12.1->cached_path->f5-tts==1.1.9) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=12.1->cached_path->f5-tts==1.1.9) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->f5-tts==1.1.9) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->f5-tts==1.1.9) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio>=5.0.0->f5-tts==1.1.9) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->f5-tts==1.1.9) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->f5-tts==1.1.9) (5.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->cached_path->f5-tts==1.1.9) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->f5-tts==1.1.9) (0.6.1)
# Downloading bitsandbytes-0.48.1-py3-none-manylinux_2_24_x86_64.whl (60.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 13.7 MB/s eta 0:00:00
# Downloading ema_pytorch-0.7.7-py3-none-any.whl (9.8 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.1 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 2.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.7 MB/s eta 0:00:00
# Downloading x_transformers-2.8.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 11.1 MB/s eta 0:00:00
# Downloading cached_path-1.8.0-py3-none-any.whl (37 kB)
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 59.3 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 28.6 MB/s eta 0:00:00
# Downloading torchdiffeq-0.2.5-py3-none-any.whl (32 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 29.8 MB/s eta 0:00:00
# Downloading vocos-0.1.0-py3-none-any.whl (24 kB)
# Downloading boto3-1.40.47-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 18.2 MB/s eta 0:00:00
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 13.7 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.1 MB/s eta 0:00:00
# Downloading botocore-1.40.47-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 118.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 11.0 MB/s eta 0:00:00
# Building wheels for collected packages: f5-tts, transformers_stream_generator, encodec
#   Building editable for f5-tts (pyproject.toml) ... done
#   Created wheel for f5-tts: filename=f5_tts-1.1.9-0.editable-py3-none-any.whl size=6755 sha256=4d28299e911e279fc2946bc27699ef0c3ac672c0aab99a061c9f5ac0f0cc1cd0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hsih0f0g/wheels/81/62/23/2e0e6471878522746bb3910e86e01000061938b59967f2c389
#   Building wheel for transformers_stream_generator (setup.py) ... done
#   Created wheel for transformers_stream_generator: filename=transformers_stream_generator-0.0.5-py3-none-any.whl size=12426 sha256=7fb27fe4ce429dd047060be56d10404fdb9d1bd64563c317560f6444fa48ee45
#   Stored in directory: /root/.cache/pip/wheels/a8/58/d2/014cb67c3cc6def738c1b1635dbf4e3dab6fb63aba7070dce0
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45759 sha256=ee3f7816e0b1ecd7da1c7207c60dab0959b1a5f0e96c375b981afacb8645ba1a
#   Stored in directory: /root/.cache/pip/wheels/b8/eb/9f/e13610cc46ab39d3199fbabebd1c3e142d44b679526e0f228a
# Successfully built f5-tts transformers_stream_generator encodec
# Installing collected packages: unidecode, tomli, pypinyin, pydantic-core, loguru, jmespath, pydantic, hydra-core, einx, botocore, s3transfer, x_transformers, torchdiffeq, ema_pytorch, boto3, bitsandbytes, transformers_stream_generator, encodec, vocos, cached_path, f5-tts
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.9
#     Uninstalling pydantic-2.11.9:
#       Successfully uninstalled pydantic-2.11.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mcp 1.15.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 2.10.6 which is incompatible.
# Successfully installed bitsandbytes-0.48.1 boto3-1.40.47 botocore-1.40.47 cached_path-1.8.0 einx-0.3.0 ema_pytorch-0.7.7 encodec-0.1.1 f5-tts-1.1.9 hydra-core-1.3.2 jmespath-1.0.1 loguru-0.7.3 pydantic-2.10.6 pydantic-core-2.27.2 pypinyin-0.55.0 s3transfer-0.14.0 tomli-2.2.1 torchdiffeq-0.2.5 transformers_stream_generator-0.0.5 unidecode-1.4.0 vocos-0.1.0 x_transformers-2.8.2
# Requirement already satisfied: cached_path in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from cached_path) (2.32.4)
# Requirement already satisfied: rich<14.0,>=12.1 in /usr/local/lib/python3.12/dist-packages (from cached_path) (13.9.4)
# Requirement already satisfied: filelock<4.0,>=3.4 in /usr/local/lib/python3.12/dist-packages (from cached_path) (3.19.1)
# Requirement already satisfied: boto3<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from cached_path) (1.40.47)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from cached_path) (2.19.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from cached_path) (0.35.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from cached_path) (25.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.47 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.0->cached_path) (1.40.47)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.0->cached_path) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0,>=1.0->cached_path) (0.14.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path) (1.7.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->cached_path) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->cached_path) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->cached_path) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->cached_path) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=12.1->cached_path) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=12.1->cached_path) (2.19.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.47->boto3<2.0,>=1.0->cached_path) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->cached_path) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.47->boto3<2.0,>=1.0->cached_path) (1.17.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from librosa) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from torchaudio) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchaudio) (3.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->torchaudio) (3.0.3)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.47.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.118.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.35.3)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.6)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.19.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.37.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.19.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
# Create a proper dataset directory
# !mkdir -p /content/dataset/audio
# !mkdir -p /content/dataset/metadata

# Move TSV files to metadata folder
# !mv /content/F5-TTS/*.tsv /content/dataset/metadata/

# %%
from huggingface_hub import login
import os

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    decoder_start_token_id: int

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, torch.Tensor]:
        # 1. Gather raw audio features
        input_feats = [feat["input_features"] for feat in features]
        # 2. Pad them (this returns both 'input_features' and 'attention_mask')
        batch_inputs = self.processor.feature_extractor.pad(
            {"input_features": input_feats},
            padding=True,
            return_tensors="pt",
            return_attention_mask=True,
        )

        # 3. Gather label sequences
        label_ids = [feat["labels"] for feat in features]
        # 4. Pad them (this returns 'input_ids' and its 'attention_mask')
        label_batch = self.processor.tokenizer.pad(
            {"input_ids": label_ids},
            padding=True,
            return_tensors="pt",
            return_attention_mask=True,
        )

        # 5. Replace pad token ids in labels with -100 so they're ignored in loss
        labels = label_batch["input_ids"].masked_fill(
            label_batch["attention_mask"].ne(1), -100
        )

        # 6. If a bos token was prepended earlier, drop it here
        if labels.size(1) > 0 and torch.all(labels[:, 0] == self.decoder_start_token_id):
            labels = labels[:, 1:]

        # 7. Package everything up
        batch_inputs["labels"] = labels
        # and give the decoder its own attention mask
        batch_inputs["decoder_attention_mask"] = label_batch["attention_mask"]

        return batch_inputs

# %%
# ----------------------------------
# Configuration – edit as you like
# ----------------------------------
MODEL_ID = "openai/whisper-base"
HF_USERNAME = "newModl"               #  <-- CHANGE
PUSH_MODEL_ID = f"{HF_USERNAME}/whisper-base-urdu-full"
LANG_ID = "ur"
SAMPLING_RATE = 24_000
SEED = 666

# %%
pip install datasets==3.6.0
# Out:
# Collecting datasets==3.6.0
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.35.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 34.0 MB/s eta 0:00:00
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed datasets-3.6.0

# %%
import os, re, random, torch, numpy as np
from datasets import load_dataset, Audio
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import torch

# %%
# Load Common Voice 17.0 Urdu subset
dataset = load_dataset(
    "mozilla-foundation/common_voice_17_0",
    LANG_ID,
    split={
        "train": "train+validation",
        "test":  "test[:600]"
    },
    cache_dir="./hf_cache",
    trust_remote_code=True
)

# Remove imports with missing audio
dataset = dataset.remove_columns(
    [col for col in dataset["train"].column_names if col not in ("audio","sentence")]
)

print(dataset)
# Out:
# README.md:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# common_voice_17_0.py:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# languages.py:   0%|          | 0.00/3.92k [00:00<?, ?B/s]
# release_stats.py:   0%|          | 0.00/132k [00:00<?, ?B/s]
# n_shards.json:   0%|          | 0.00/17.5k [00:00<?, ?B/s]
# audio/ur/train/ur_train_0.tar:   0%|          | 0.00/140M [00:00<?, ?B/s]
# audio/ur/dev/ur_dev_0.tar:   0%|          | 0.00/102M [00:00<?, ?B/s]
# audio/ur/test/ur_test_0.tar:   0%|          | 0.00/116M [00:00<?, ?B/s]
# audio/ur/other/ur_other_0.tar:   0%|          | 0.00/982M [00:00<?, ?B/s]
# audio/ur/other/ur_other_1.tar:   0%|          | 0.00/953M [00:00<?, ?B/s]
# audio/ur/other/ur_other_2.tar:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# audio/ur/other/ur_other_3.tar:   0%|          | 0.00/465M [00:00<?, ?B/s]
# audio/ur/invalidated/ur_invalidated_0.ta(…):   0%|          | 0.00/177M [00:00<?, ?B/s]
# audio/ur/validated/ur_validated_0.tar:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# audio/ur/validated/ur_validated_1.tar:   0%|          | 0.00/323M [00:00<?, ?B/s]
# train.tsv:   0%|          | 0.00/1.75M [00:00<?, ?B/s]
# dev.tsv:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# test.tsv:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# transcript/ur/other.tsv:   0%|          | 0.00/45.1M [00:00<?, ?B/s]
# invalidated.tsv:   0%|          | 0.00/2.30M [00:00<?, ?B/s]
# transcript/ur/validated.tsv:   0%|          | 0.00/17.6M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 5368it [00:00, 122443.45it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 4057it [00:00, 98167.14it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 4056it [00:00, 71524.48it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 13043it [00:00, 130413.02it/s]
# Reading metadata...: 26085it [00:00, 116598.30it/s]
# Reading metadata...: 37841it [00:00, 94765.29it/s]
# Reading metadata...: 47698it [00:00, 86036.35it/s]
# Reading metadata...: 56546it [00:00, 82936.38it/s]
# Reading metadata...: 64967it [00:00, 80214.95it/s]
# Reading metadata...: 73051it [00:00, 79040.38it/s]
# Reading metadata...: 80986it [00:00, 77193.20it/s]
# Reading metadata...: 88717it [00:01, 75696.08it/s]
# Reading metadata...: 96288it [00:01, 75594.70it/s]
# Reading metadata...: 103848it [00:01, 75375.11it/s]
# Reading metadata...: 111772it [00:01, 76498.06it/s]
# Reading metadata...: 119533it [00:01, 76821.02it/s]
# Reading metadata...: 127219it [00:01, 76799.96it/s]
# Reading metadata...: 135861it [00:01, 80540.29it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 6818it [00:00, 104080.96it/s]
# Generating validated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 7872it [00:00, 78708.07it/s]
# Reading metadata...: 16216it [00:00, 81484.23it/s]
# Reading metadata...: 24456it [00:00, 81895.97it/s]
# Reading metadata...: 32646it [00:00, 78402.42it/s]
# Reading metadata...: 40508it [00:00, 75994.21it/s]
# Reading metadata...: 53858it [00:00, 77949.19it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 9425
#     })
#     test: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 600
#     })
# })

# %%
import os
import pandas as pd
from datasets import load_dataset
import soundfile as sf
from tqdm import tqdm

print("=" * 70)
print("Preparing Urdu Common Voice Dataset for F5-TTS Training")
print("=" * 70)

# Step 1: Load the dataset from HuggingFace
print("\n[1/4] Loading dataset from HuggingFace...")
dataset = load_dataset("mozilla-foundation/common_voice_17_0", "ur", split="train")
test_dataset = load_dataset("mozilla-foundation/common_voice_17_0", "ur", split="test")

print(f"✓ Train samples: {len(dataset)}")
print(f"✓ Test samples: {len(test_dataset)}")

# Step 2: Create output directories
print("\n[2/4] Creating directories...")
OUTPUT_DIR = "/content/f5_tts_dataset"
AUDIO_DIR = f"{OUTPUT_DIR}/audio"
os.makedirs(AUDIO_DIR, exist_ok=True)
print(f"✓ Created: {OUTPUT_DIR}")

# Step 3: Extract and save audio files + metadata
print("\n[3/4] Extracting audio files and creating metadata...")
print("This may take a few minutes...")

metadata = []
error_count = 0

# Process training data
for idx, item in enumerate(tqdm(dataset, desc="Processing train")):
    try:
        # Get audio data
        audio_data = item['audio']
        audio_array = audio_data['array']
        sample_rate = audio_data['sampling_rate']

        # Get transcription
        transcription = item['sentence']

        # Skip if transcription is empty
        if not transcription or len(transcription.strip()) == 0:
            continue

        # Create filename
        audio_filename = f"train_{idx:06d}.wav"
        audio_path = os.path.join(AUDIO_DIR, audio_filename)

        # Save audio file
        sf.write(audio_path, audio_array, sample_rate)

        # Add to metadata
        metadata.append({
            'audio_path': f"audio/{audio_filename}",
            'text': transcription,
            'duration': len(audio_array) / sample_rate
        })

    except Exception as e:
        error_count += 1
        if error_count <= 5:
            print(f"Error processing sample {idx}: {e}")

print(f"✓ Processed {len(metadata)} training samples")
print(f"✓ Errors: {error_count}")

# Step 4: Filter by duration (optional but recommended)
print("\n[4/4] Filtering by duration...")
df = pd.DataFrame(metadata)

print(f"Original samples: {len(df)}")
print(f"Duration range: {df['duration'].min():.2f}s - {df['duration'].max():.2f}s")

# Filter: keep only 1-15 second clips (recommended for TTS)
df_filtered = df[(df['duration'] >= 1.0) & (df['duration'] <= 15.0)]
print(f"After filtering (1-15s): {len(df_filtered)} samples")

# Calculate total duration
total_hours = df_filtered['duration'].sum() / 3600
print(f"Total audio duration: {total_hours:.2f} hours")

# Save metadata
metadata_path = f"{OUTPUT_DIR}/metadata.csv"
df_filtered[['audio_path', 'text']].to_csv(metadata_path, index=False)
print(f"✓ Metadata saved to: {metadata_path}")

# Step 5: Create train/validation split
print("\n[5/5] Creating train/validation split...")
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(df_filtered, test_size=0.1, random_state=42)

train_metadata_path = f"{OUTPUT_DIR}/train_metadata.csv"
val_metadata_path = f"{OUTPUT_DIR}/val_metadata.csv"

train_df[['audio_path', 'text']].to_csv(train_metadata_path, index=False)
val_df[['audio_path', 'text']].to_csv(val_metadata_path, index=False)

print(f"✓ Train samples: {len(train_df)} ({train_df['duration'].sum()/3600:.2f} hours)")
print(f"✓ Val samples: {len(val_df)} ({val_df['duration'].sum()/3600:.2f} hours)")
print(f"✓ Train metadata: {train_metadata_path}")
print(f"✓ Val metadata: {val_metadata_path}")

# Display sample data
print("\n" + "=" * 70)
print("Sample Data:")
print("=" * 70)
print(train_df[['audio_path', 'text', 'duration']].head(3))

# Verify files exist
print("\n" + "=" * 70)
print("Verification:")
print("=" * 70)
sample_path = os.path.join(OUTPUT_DIR, train_df.iloc[0]['audio_path'])
if os.path.exists(sample_path):
    print(f"✓ Audio files verified: {sample_path}")
else:
    print(f"✗ Error: Sample file not found: {sample_path}")

print("\n" + "=" * 70)
print("Dataset Preparation Complete!")
print("=" * 70)
print(f"\nYour dataset is ready at: {OUTPUT_DIR}")
print(f"- Audio files: {AUDIO_DIR}")
print(f"- Train metadata: {train_metadata_path}")
print(f"- Val metadata: {val_metadata_path}")
print(f"\nTotal training data: {len(train_df)} samples, {train_df['duration'].sum()/3600:.2f} hours")
print("\n✓ You can now proceed with F5-TTS fine-tuning!")
# Out:
# ======================================================================
# Preparing Urdu Common Voice Dataset for F5-TTS Training
# ======================================================================
#
# [1/4] Loading dataset from HuggingFace...
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 5368it [00:00, 66082.27it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 4057it [00:00, 61865.95it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 4056it [00:00, 109236.77it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 12737it [00:00, 127354.33it/s]
# Reading metadata...: 25473it [00:00, 126343.54it/s]
# Reading metadata...: 38527it [00:00, 128246.27it/s]
# Reading metadata...: 51353it [00:00, 120074.70it/s]
# Reading metadata...: 63479it [00:00, 120481.04it/s]
# Reading metadata...: 75716it [00:00, 121101.59it/s]
# Reading metadata...: 87860it [00:00, 119769.57it/s]
# Reading metadata...: 99861it [00:00, 119168.41it/s]
# Reading metadata...: 111794it [00:00, 116087.19it/s]
# Reading metadata...: 123990it [00:01, 117840.66it/s]
# Reading metadata...: 135861it [00:01, 119329.51it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 6818it [00:00, 116108.72it/s]
# Generating validated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 12959it [00:00, 129567.88it/s]
# Reading metadata...: 25916it [00:00, 128829.37it/s]
# Reading metadata...: 38830it [00:00, 128952.49it/s]
# Reading metadata...: 53858it [00:00, 123129.57it/s]
# ✓ Train samples: 5368
# ✓ Test samples: 4056
#
# [2/4] Creating directories...
# ✓ Created: /content/f5_tts_dataset
#
# [3/4] Extracting audio files and creating metadata...
# This may take a few minutes...
# Processing train: 100%|██████████| 5368/5368 [01:27<00:00, 61.36it/s]
# ✓ Processed 5368 training samples
# ✓ Errors: 0
#
# [4/4] Filtering by duration...
# Original samples: 5368
# Duration range: 0.32s - 10.48s
# After filtering (1-15s): 5367 samples
# Total audio duration: 6.28 hours
# ✓ Metadata saved to: /content/f5_tts_dataset/metadata.csv
#
# [5/5] Creating train/validation split...
# ✓ Train samples: 4830 (5.64 hours)
# ✓ Val samples: 537 (0.64 hours)
# ✓ Train metadata: /content/f5_tts_dataset/train_metadata.csv
# ✓ Val metadata: /content/f5_tts_dataset/val_metadata.csv
#
# ======================================================================
# Sample Data:
# ======================================================================
#                   audio_path  \
# 1344  audio/train_001344.wav
# 3085  audio/train_003085.wav
# 1244  audio/train_001244.wav
#
#                                                    text  duration
# 1344               میں آپ کو حوالات میں بند کروا دوں گا     3.240
# 3085  اٹھارہویں صدی میں قائم ہونے والے کوئٹہ کو آب و...     9.108
# 1244  کامن ویلتھ گیمزپاکستانی ریسلر نے کانسی کا تمغہ...     5.436
#
# ======================================================================
# Verification:
# ======================================================================
# ✓ Audio files verified: /content/f5_tts_dataset/audio/train_001344.wav
#
# ======================================================================
# Dataset Preparation Complete!
# ======================================================================
#
# Your dataset is ready at: /content/f5_tts_dataset
# - Audio files: /content/f5_tts_dataset/audio
# - Train metadata: /content/f5_tts_dataset/train_metadata.csv
# - Val metadata: /content/f5_tts_dataset/val_metadata.csv
#
# Total training data: 4830 samples, 5.64 hours
#
# ✓ You can now proceed with F5-TTS fine-tuning!

# %%
# Mount Google Drive if not already mounted
from google.colab import drive
drive.mount('/content/drive')

# Copy the entire dataset to Drive
print("Copying dataset to Google Drive...")
# !cp -r /content/f5_tts_dataset /content/drive/MyDrive/F5-TTS-Urdu-Dataset

print("✓ Dataset saved to Google Drive!")
print("Location: /content/drive/MyDrive/F5-TTS-Urdu-Dataset")
# Out:
# Mounted at /content/drive
# Copying dataset to Google Drive...
# ✓ Dataset saved to Google Drive!
# Location: /content/drive/MyDrive/F5-TTS-Urdu-Dataset

# %%
# Create a zip file
print("Creating zip archive...")
# !cd /content && zip -r f5_tts_dataset.zip f5_tts_dataset/

# Download the zip
from google.colab import files
print("Starting download...")
files.download('/content/f5_tts_dataset.zip')

print("✓ Download started! Check your browser downloads.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: f5_tts_dataset/audio/train_000475.wav (deflated 49%)
#   adding: f5_tts_dataset/audio/train_001521.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_001542.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_003038.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004291.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003394.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003402.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004699.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005081.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001693.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_003778.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_001497.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002903.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004441.wav (deflated 49%)
#   adding: f5_tts_dataset/audio/train_001570.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_005181.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000588.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002797.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_005152.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001230.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_004089.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001595.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_004322.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_005204.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003497.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005283.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002714.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003477.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002960.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002780.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_002211.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001842.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000720.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003867.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_005008.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_004148.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004182.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_000764.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001107.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003674.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002662.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002213.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_000277.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003750.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000063.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_000712.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001292.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002602.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000062.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_003313.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_001045.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_003114.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000228.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004892.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000775.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_004036.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_001495.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003813.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_002747.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_001914.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002997.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002807.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004804.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000360.wav (deflated 13%)
#   adding: f5_tts_dataset/audio/train_000795.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001053.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003322.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000856.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000523.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_003691.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_002774.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004590.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_002588.wav (deflated 56%)
#   adding: f5_tts_dataset/audio/train_005113.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003519.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_002387.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_002146.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000781.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_004260.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002191.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_000802.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004522.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_002856.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003687.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_004323.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_003331.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004997.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_005087.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_002921.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003575.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000444.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003839.wav (deflated 49%)
#   adding: f5_tts_dataset/audio/train_003289.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001321.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002763.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_000197.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000565.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000937.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_002008.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001459.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000383.wav (deflated 11%)
#   adding: f5_tts_dataset/audio/train_003771.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004418.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_005218.wav (deflated 58%)
#   adding: f5_tts_dataset/audio/train_004385.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_001474.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_002560.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002380.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004731.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004198.wav (deflated 45%)
#   adding: f5_tts_dataset/audio/train_003508.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001597.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000469.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_001213.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_001541.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004673.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003651.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001719.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_001275.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001101.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004181.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_002122.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_002089.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_001347.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005139.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000487.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_002400.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_003915.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003777.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_002850.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004840.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_002615.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_001588.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001576.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001969.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001400.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_003557.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003541.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003971.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_003226.wav (deflated 45%)
#   adding: f5_tts_dataset/audio/train_003182.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_002757.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_000170.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002243.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_003366.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002891.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001304.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002046.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003697.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_003742.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_004956.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_005349.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000447.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_003485.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002241.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000686.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_004514.wav (deflated 57%)
#   adding: f5_tts_dataset/audio/train_001787.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_004972.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004824.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_002589.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_000034.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004614.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000729.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000658.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003851.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_003782.wav (deflated 51%)
#   adding: f5_tts_dataset/audio/train_004999.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003734.wav (deflated 46%)
#   adding: f5_tts_dataset/audio/train_001434.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003609.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005102.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_003140.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003406.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002958.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000173.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003480.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000604.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_004128.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001438.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_003325.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003618.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002536.wav (deflated 44%)
#   adding: f5_tts_dataset/audio/train_002917.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003278.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000364.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_002126.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004823.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_002284.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_004992.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002285.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_003205.wav (deflated 46%)
#   adding: f5_tts_dataset/audio/train_002781.wav (deflated 61%)
#   adding: f5_tts_dataset/audio/train_004656.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003128.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_004634.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001057.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001878.wav (deflated 51%)
#   adding: f5_tts_dataset/audio/train_000465.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_004369.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_004690.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000840.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000621.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_004701.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003603.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004375.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_005129.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000718.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003435.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002498.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_001746.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004532.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_001189.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002803.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001263.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_004689.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000524.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_004421.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_002446.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002727.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_005320.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001594.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_004939.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000613.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_004795.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_003501.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001990.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_004602.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_005277.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001853.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000124.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001352.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001436.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001514.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002052.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002598.wav (deflated 76%)
#   adding: f5_tts_dataset/audio/train_000926.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_004533.wav (deflated 13%)
#   adding: f5_tts_dataset/audio/train_000556.wav (deflated 52%)
#   adding: f5_tts_dataset/audio/train_003542.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004926.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001465.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005024.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000003.wav (deflated 47%)
#   adding: f5_tts_dataset/audio/train_004916.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_003349.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000271.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001348.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003982.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_004885.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003748.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000378.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_003482.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001190.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001557.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001956.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000352.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_000857.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000353.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_003433.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000316.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_003002.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003988.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_000727.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_003861.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005318.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003825.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004247.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002182.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003340.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000928.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004912.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002465.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_004637.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000911.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_004852.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000550.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_004944.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_005169.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004535.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_002490.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_003197.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000407.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_001600.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_000335.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_004597.wav (deflated 12%)
#   adding: f5_tts_dataset/audio/train_004822.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_004599.wav (deflated 13%)
#   adding: f5_tts_dataset/audio/train_003696.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003133.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000558.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004456.wav (deflated 62%)
#   adding: f5_tts_dataset/audio/train_001707.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003496.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001528.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002982.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002467.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_001162.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_001895.wav (deflated 51%)
#   adding: f5_tts_dataset/audio/train_004253.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000127.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001378.wav (deflated 13%)
#   adding: f5_tts_dataset/audio/train_000535.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_004020.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_003156.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_001494.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003287.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003958.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_004290.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_003619.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003078.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_004252.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003047.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001123.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_005147.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000224.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002753.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003250.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_001857.wav (deflated 47%)
#   adding: f5_tts_dataset/audio/train_002886.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_001864.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001268.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004600.wav (deflated 13%)
#   adding: f5_tts_dataset/audio/train_002940.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002992.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_002024.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_005224.wav (deflated 55%)
#   adding: f5_tts_dataset/audio/train_005194.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_002232.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001764.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002501.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_002368.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004000.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004118.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002928.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003437.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003115.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000505.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_003326.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_001783.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002217.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004112.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004816.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002785.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_000653.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001741.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_005201.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000611.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004327.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002730.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_001944.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_005032.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001302.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001859.wav (deflated 45%)
#   adding: f5_tts_dataset/audio/train_001093.wav (deflated 45%)
#   adding: f5_tts_dataset/audio/train_002123.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003138.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003098.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002290.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_004909.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003353.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_004203.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_001537.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_003188.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000220.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004942.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000631.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_001718.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004496.wav (deflated 54%)
#   adding: f5_tts_dataset/audio/train_004300.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_002172.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001608.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002157.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000539.wav (deflated 51%)
#   adding: f5_tts_dataset/audio/train_003525.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001845.wav (deflated 52%)
#   adding: f5_tts_dataset/audio/train_001798.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002300.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002722.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002162.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003866.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003571.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004167.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000051.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_001286.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_003068.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004191.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003908.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000205.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002765.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_003940.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_005077.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_000296.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_003641.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002840.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000677.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001064.wav (deflated 53%)
#   adding: f5_tts_dataset/audio/train_005214.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_000435.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000413.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000721.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001626.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004317.wav (deflated 51%)
#   adding: f5_tts_dataset/audio/train_005237.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004943.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000809.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_003103.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003716.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000914.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002179.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002673.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004152.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002324.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_002545.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_004630.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_001700.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_002987.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004946.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004988.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_004146.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000909.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004524.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_003504.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000090.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002259.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_001331.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001172.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_001625.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003704.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002101.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003815.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_005359.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_003080.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_000838.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003761.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003116.wav (deflated 56%)
#   adding: f5_tts_dataset/audio/train_003752.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003712.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_002899.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000545.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_000542.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_003793.wav (deflated 46%)
#   adding: f5_tts_dataset/audio/train_004825.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003965.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_002614.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_002173.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_005143.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_005067.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_004226.wav (deflated 46%)
#   adding: f5_tts_dataset/audio/train_005332.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000011.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_000765.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000037.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_002423.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_003028.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003981.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000682.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003948.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001728.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001735.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_000948.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001274.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000861.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_004162.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002161.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002611.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000139.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_003923.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000627.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004645.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_004735.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000128.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_005167.wav (deflated 47%)
#   adding: f5_tts_dataset/audio/train_004561.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_003822.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001832.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003760.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002912.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_004251.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004156.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002663.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003218.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002520.wav (deflated 44%)
#   adding: f5_tts_dataset/audio/train_003104.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_000610.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_001473.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002702.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003458.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_002689.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_005101.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000015.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002742.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_004484.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_005241.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004798.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003350.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003680.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000031.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_000448.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004136.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003246.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000975.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_003019.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_001780.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001682.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003153.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000642.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_002530.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001995.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_003231.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004052.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_003281.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_005030.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003676.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002814.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002114.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001898.wav (deflated 52%)
#   adding: f5_tts_dataset/audio/train_004616.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_001007.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_000921.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002868.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_000102.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_002151.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_004249.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002030.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002492.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_001301.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_004485.wav (deflated 55%)
#   adding: f5_tts_dataset/audio/train_002318.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000971.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_003379.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004548.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_005211.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000762.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000951.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002132.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002280.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004882.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001476.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001198.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000998.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004027.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_003000.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_002337.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002796.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_002197.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002401.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003647.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000253.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004098.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002080.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002916.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000595.wav (deflated 46%)
#   adding: f5_tts_dataset/audio/train_003631.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_005119.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004078.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003067.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004012.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003553.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002418.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002620.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_004490.wav (deflated 47%)
#   adding: f5_tts_dataset/audio/train_003233.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004576.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003640.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_005010.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000572.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_004072.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001096.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000864.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_004121.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_002808.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003906.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_003057.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002416.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000922.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000895.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_005192.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000350.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_001981.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004115.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003722.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_005364.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002016.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_000359.wav (deflated 9%)
#   adding: f5_tts_dataset/audio/train_000291.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003190.wav (deflated 47%)
#   adding: f5_tts_dataset/audio/train_000640.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_002918.wav (deflated 49%)
#   adding: f5_tts_dataset/audio/train_005133.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_003856.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_002041.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_004783.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_003531.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_002964.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_004014.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002557.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_002373.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001154.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003692.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_000044.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_005122.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003772.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003628.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000579.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000185.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000496.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_004221.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001032.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_002700.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002325.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_002116.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000714.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_002935.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003020.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_002267.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000962.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_003390.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_003417.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004539.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_000767.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001239.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_005156.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_002676.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000222.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001894.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003031.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002338.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001193.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002276.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004003.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_005212.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005252.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_005210.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000626.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001013.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_000733.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_000679.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000719.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_001178.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_005082.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_002047.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000930.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_002005.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004464.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_003547.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_004356.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001109.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_000100.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_003008.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_001026.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_001279.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000133.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_001049.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004150.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001506.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_004683.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003842.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_004867.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003130.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000250.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_005184.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000875.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_001038.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003279.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004622.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_001410.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_003633.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002973.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001290.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003249.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004913.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000643.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003884.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000042.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_000380.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_005198.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000728.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000526.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_005292.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_004663.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_005339.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_001681.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001912.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004884.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002718.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000057.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_004873.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_000112.wav (deflated 45%)
#   adding: f5_tts_dataset/audio/train_000694.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002926.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000701.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000274.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_005239.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001440.wav (deflated 56%)
#   adding: f5_tts_dataset/audio/train_002731.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_003391.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003419.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001516.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003652.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001664.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_001679.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003006.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000561.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_002452.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_004455.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_003829.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_004832.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003919.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003741.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_000938.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000944.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003672.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004417.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000680.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_005153.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_002579.wav (deflated 49%)
#   adding: f5_tts_dataset/audio/train_004750.wav (deflated 44%)
#   adding: f5_tts_dataset/audio/train_000080.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004306.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002433.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000837.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003711.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002263.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_003352.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001922.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004100.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004231.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_003725.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003806.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_004213.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002632.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_001632.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001366.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_002317.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003254.wav (deflated 44%)
#   adding: f5_tts_dataset/audio/train_004629.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_003812.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004311.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002233.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000096.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002108.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_001954.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003054.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001750.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003418.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_004282.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004923.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_004585.wav (deflated 11%)
#   adding: f5_tts_dataset/audio/train_004001.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_004206.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_003446.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003403.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002956.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_003887.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001285.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004444.wav (deflated 48%)
#   adding: f5_tts_dataset/audio/train_001325.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003922.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001324.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000963.wav (deflated 41%)
# ...
#   adding: f5_tts_dataset/audio/train_000576.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_002383.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002625.wav (deflated 59%)
#   adding: f5_tts_dataset/audio/train_003623.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_002654.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_000432.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_005311.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_005225.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_003702.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004976.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_001835.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000184.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000008.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004041.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_003235.wav (deflated 40%)
#   adding: f5_tts_dataset/audio/train_001993.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_002477.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000670.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002681.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003236.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004844.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_002269.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001050.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_000896.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_001437.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004037.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_000780.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003746.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_002553.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_005103.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_004937.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002028.wav (deflated 43%)
#   adding: f5_tts_dataset/audio/train_001132.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003844.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002244.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003841.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_003081.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000497.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_001524.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_003549.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001174.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003543.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_004849.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004366.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000756.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003157.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003420.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003049.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002042.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000070.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_004604.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_003699.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004480.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000468.wav (deflated 50%)
#   adding: f5_tts_dataset/audio/train_000299.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002776.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001066.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_002931.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004255.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000532.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004747.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003688.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001800.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004987.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003084.wav (deflated 60%)
#   adding: f5_tts_dataset/audio/train_000525.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_000583.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002801.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_000760.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000366.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_004298.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000072.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_005006.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_001217.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_003860.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001674.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_002947.wav (deflated 54%)
#   adding: f5_tts_dataset/audio/train_005117.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001622.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_000249.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002144.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_003574.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002004.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_000945.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_002896.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_001955.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000485.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003604.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001376.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001201.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_000287.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000404.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001060.wav (deflated 51%)
#   adding: f5_tts_dataset/audio/train_003916.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003807.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_005003.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002268.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_003039.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001404.wav (deflated 13%)
#   adding: f5_tts_dataset/audio/train_002103.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_005335.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_005249.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_000725.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000593.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002680.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000379.wav (deflated 8%)
#   adding: f5_tts_dataset/audio/train_000343.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_004566.wav (deflated 14%)
#   adding: f5_tts_dataset/audio/train_000709.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003027.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000927.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001544.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_004588.wav (deflated 8%)
#   adding: f5_tts_dataset/audio/train_003034.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_001294.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_001423.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_002837.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004184.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_001014.wav (deflated 55%)
#   adding: f5_tts_dataset/audio/train_000482.wav (deflated 62%)
#   adding: f5_tts_dataset/audio/train_002609.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_000882.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000533.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_004101.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001816.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000630.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_005079.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_005068.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_001509.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_000584.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_002849.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_005344.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_003073.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_003089.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_001480.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001312.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_001499.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003578.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_001744.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000406.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004049.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_000488.wav (deflated 41%)
#   adding: f5_tts_dataset/audio/train_002361.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_001699.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003998.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_000978.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_001889.wav (deflated 49%)
#   adding: f5_tts_dataset/audio/train_001613.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_002637.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_004321.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_002708.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_002074.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004332.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_005256.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004706.wav (deflated 37%)
#   adding: f5_tts_dataset/audio/train_002897.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_005262.wav (deflated 45%)
#   adding: f5_tts_dataset/audio/train_000605.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002294.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_003582.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_000615.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_003634.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_001571.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_000777.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002339.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_001712.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_005134.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_001211.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_004968.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_004985.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_002898.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000454.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_004772.wav (deflated 16%)
#   adding: f5_tts_dataset/audio/train_000324.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_003645.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000165.wav (deflated 42%)
#   adding: f5_tts_dataset/audio/train_003167.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_000269.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_003627.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001409.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_002104.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_004808.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_004713.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004748.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001819.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_005061.wav (deflated 36%)
#   adding: f5_tts_dataset/audio/train_000235.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_001848.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_004793.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001678.wav (deflated 30%)
#   adding: f5_tts_dataset/audio/train_003991.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_003066.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_002563.wav (deflated 38%)
#   adding: f5_tts_dataset/audio/train_004578.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_000237.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_002910.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000666.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004771.wav (deflated 17%)
#   adding: f5_tts_dataset/audio/train_004978.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_004688.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003059.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_001184.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_005203.wav (deflated 15%)
#   adding: f5_tts_dataset/audio/train_002092.wav (deflated 62%)
#   adding: f5_tts_dataset/audio/train_003321.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_000751.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003408.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_001739.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_002816.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_001642.wav (deflated 35%)
#   adding: f5_tts_dataset/audio/train_000716.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003275.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002189.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_005330.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_004891.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000587.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_001992.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000243.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_000282.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_005111.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_004299.wav (deflated 32%)
#   adding: f5_tts_dataset/audio/train_001822.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_005228.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_000594.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_004488.wav (deflated 33%)
#   adding: f5_tts_dataset/audio/train_004276.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_001164.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000753.wav (deflated 34%)
#   adding: f5_tts_dataset/audio/train_004076.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_000652.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_005062.wav (deflated 60%)
#   adding: f5_tts_dataset/audio/train_003198.wav (deflated 21%)
#   adding: f5_tts_dataset/audio/train_002021.wav (deflated 26%)
#   adding: f5_tts_dataset/audio/train_004108.wav (deflated 31%)
#   adding: f5_tts_dataset/audio/train_001073.wav (deflated 22%)
#   adding: f5_tts_dataset/audio/train_000661.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_003613.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_000471.wav (deflated 39%)
#   adding: f5_tts_dataset/audio/train_005137.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_003327.wav (deflated 25%)
#   adding: f5_tts_dataset/audio/train_002040.wav (deflated 46%)
#   adding: f5_tts_dataset/audio/train_002292.wav (deflated 18%)
#   adding: f5_tts_dataset/audio/train_003611.wav (deflated 24%)
#   adding: f5_tts_dataset/audio/train_005345.wav (deflated 28%)
#   adding: f5_tts_dataset/audio/train_004404.wav (deflated 20%)
#   adding: f5_tts_dataset/audio/train_001862.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003681.wav (deflated 27%)
#   adding: f5_tts_dataset/audio/train_001551.wav (deflated 29%)
#   adding: f5_tts_dataset/audio/train_004134.wav (deflated 23%)
#   adding: f5_tts_dataset/audio/train_003607.wav (deflated 19%)
#   adding: f5_tts_dataset/audio/train_001918.wav (deflated 20%)
#   adding: f5_tts_dataset/metadata.csv (deflated 72%)
#   adding: f5_tts_dataset/train_metadata.csv (deflated 72%)
# Starting download...
# ✓ Download started! Check your browser downloads.

# %%
# Navigate to F5-TTS directory
# %cd /content/F5-TTS

# List available scripts
# !ls -la

# Check for training scripts
# !find . -name "*train*" -type f | head -10

# Check the src structure
# !ls -la src/f5_tts/ 2>/dev/null || ls -la f5_tts/ 2>/dev/null
# Out:
# /content/F5-TTS
# total 72
# drwxr-xr-x 8 root root 4096 Oct  7 21:16 .
# drwxr-xr-x 1 root root 4096 Oct  7 21:23 ..
# drwxr-xr-x 2 root root 4096 Oct  7 21:11 ckpts
# drwxr-xr-x 3 root root 4096 Oct  7 21:11 data
# -rw-r--r-- 1 root root  865 Oct  7 21:11 Dockerfile
# drwxr-xr-x 8 root root 4096 Oct  7 21:11 .git
# drwxr-xr-x 4 root root 4096 Oct  7 21:11 .github
# -rw-r--r-- 1 root root 3202 Oct  7 21:11 .gitignore
# -rw-r--r-- 1 root root  115 Oct  7 21:11 .gitmodules
# drwxr-xr-x 4 root root 4096 Oct  7 21:18 hf_cache
# -rw-r--r-- 1 root root 1068 Oct  7 21:11 LICENSE
# -rw-r--r-- 1 root root  413 Oct  7 21:11 .pre-commit-config.yaml
# -rw-r--r-- 1 root root 1565 Oct  7 21:11 pyproject.toml
# -rw-r--r-- 1 root root 9529 Oct  7 21:11 README.md
# -rw-r--r-- 1 root root  198 Oct  7 21:11 ruff.toml
# drwxr-xr-x 5 root root 4096 Oct  7 21:11 src
# ./src/f5_tts/train/train.py
# ./src/f5_tts/model/trainer.py
# ./hf_cache/mozilla-foundation___common_voice_17_0/ur/17.0.0/9d10386a731ff6e6ed4ec973a4dc204a9820e8c842fbe388bdba0dd205ed5016/common_voice_17_0-train.arrow
# total 60
# drwxr-xr-x 9 root root 4096 Oct  7 21:11 .
# drwxr-xr-x 5 root root 4096 Oct  7 21:11 ..
# -rw-r--r-- 1 root root 5049 Oct  7 21:11 api.py
# drwxr-xr-x 2 root root 4096 Oct  7 21:11 configs
# drwxr-xr-x 2 root root 4096 Oct  7 21:11 eval
# drwxr-xr-x 3 root root 4096 Oct  7 21:11 infer
# drwxr-xr-x 3 root root 4096 Oct  7 21:11 model
# drwxr-xr-x 3 root root 4096 Oct  7 21:11 runtime
# drwxr-xr-x 2 root root 4096 Oct  7 21:11 scripts
# -rw-r--r-- 1 root root 2019 Oct  7 21:11 socket_client.py
# -rw-r--r-- 1 root root 9070 Oct  7 21:11 socket_server.py
# drwxr-xr-x 3 root root 4096 Oct  7 21:11 train

# %%
# Make sure all dependencies are installed
# !pip install -e . --quiet

# Install additional requirements if needed
# !pip install accelerate --quiet
# !pip install wandb --quiet  # Optional: for tracking training
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for f5-tts (pyproject.toml) ... done

# %%
# Verify your dataset is ready
import pandas as pd
import os

TRAIN_METADATA = "/content/f5_tts_dataset/train_metadata.csv"
VAL_METADATA = "/content/f5_tts_dataset/val_metadata.csv"

# Load and check metadata
train_df = pd.read_csv(TRAIN_METADATA)
val_df = pd.read_csv(VAL_METADATA)

print(f"✓ Training samples: {len(train_df)}")
print(f"✓ Validation samples: {len(val_df)}")
print(f"\nSample data:")
print(train_df.head(2))

# Verify first audio file exists
first_audio = os.path.join("/content/f5_tts_dataset", train_df.iloc[0]['audio_path'])
print(f"\n✓ First audio file exists: {os.path.exists(first_audio)}")
print(f"  Path: {first_audio}")
# Out:
# ✓ Training samples: 4830
# ✓ Validation samples: 537
#
# Sample data:
#                audio_path                                               text
# 0  audio/train_001344.wav               میں آپ کو حوالات میں بند کروا دوں گا
# 1  audio/train_003085.wav  اٹھارہویں صدی میں قائم ہونے والے کوئٹہ کو آب و...
#
# ✓ First audio file exists: True
#   Path: /content/f5_tts_dataset/audio/train_001344.wav

# %%
# %cd /content/F5-TTS

# Check README for training instructions
# !cat README.md | grep -A 20 -i "train" | head -40

# Look for example scripts
# !ls examples/ 2>/dev/null || echo "No examples folder"
# !ls scripts/ 2>/dev/null || echo "No scripts folder"

# Check for training files
# !find . -name "*.py" | grep -E "(train|finetune)" | head -10

# Check the main source structure
# !ls -la src/f5_tts/ 2>/dev/null || ls -la f5_tts/
# Out:
# /content/F5-TTS
# **F5-TTS**: Diffusion Transformer with ConvNeXt V2, faster trained and inference.
#
# **E2 TTS**: Flat-UNet Transformer, closest reproduction from [paper](https://arxiv.org/abs/2406.18009).
#
# **Sway Sampling**: Inference-time flow step sampling strategy, greatly improves performance
#
# ### Thanks to all the contributors !
#
# ## News
# - **2025/03/12**: 🔥 F5-TTS v1 base model with better training and inference performance. [Few demo](https://swivid.github.io/F5-TTS_updates).
# - **2024/10/08**: F5-TTS & E2 TTS base models on [🤗 Hugging Face](https://huggingface.co/SWivid/F5-TTS), [🤖 Model Scope](https://www.modelscope.cn/models/SWivid/F5-TTS_Emilia-ZH-EN), [🟣 Wisemodel](https://wisemodel.cn/models/SJTU_X-LANCE/F5-TTS_Emilia-ZH-EN).
#
# ## Installation
#
# ### Create a separate environment if needed
#
# ```bash
# # Create a conda env with python_version>=3.10  (you could also use virtualenv)
# conda create -n f5-tts python=3.11
# conda activate f5-tts
# ```
#
# ### Install PyTorch with matched device
#
# <details>
# <summary>NVIDIA GPU</summary>
#
# > ```bash
# > # Install pytorch with your CUDA version, e.g.
# > pip install torch==2.4.0+cu124 torchaudio==2.4.0+cu124 --extra-index-url https://download.pytorch.org/whl/cu124
# --
# > ### 2. Local editable (if also do training, finetuning)
# >
# > ```bash
# > git clone https://github.com/SWivid/F5-TTS.git
# > cd F5-TTS
# > # git submodule update --init --recursive  # (optional, if use bigvgan as vocoder)
# > pip install -e .
# > ```
#
# No examples folder
# No scripts folder
# ./src/f5_tts/train/finetune_cli.py
# ./src/f5_tts/train/train.py
# ./src/f5_tts/train/finetune_gradio.py
# ./src/f5_tts/train/datasets/prepare_emilia.py
# ./src/f5_tts/train/datasets/prepare_libritts.py
# ./src/f5_tts/train/datasets/prepare_emilia_v2.py
# ./src/f5_tts/train/datasets/prepare_ljspeech.py
# ./src/f5_tts/train/datasets/prepare_wenetspeech4tts.py
# ./src/f5_tts/train/datasets/prepare_csv_wavs.py
# ./src/f5_tts/model/trainer.py
# total 60
# drwxr-xr-x 9 root root 4096 Oct  7 10:03 .
# drwxr-xr-x 5 root root 4096 Oct  7 10:03 ..
# -rw-r--r-- 1 root root 5049 Oct  7 10:03 api.py
# drwxr-xr-x 2 root root 4096 Oct  7 10:03 configs
# drwxr-xr-x 2 root root 4096 Oct  7 10:03 eval
# drwxr-xr-x 3 root root 4096 Oct  7 10:03 infer
# drwxr-xr-x 3 root root 4096 Oct  7 10:03 model
# drwxr-xr-x 3 root root 4096 Oct  7 10:03 runtime
# drwxr-xr-x 2 root root 4096 Oct  7 10:03 scripts
# -rw-r--r-- 1 root root 2019 Oct  7 10:03 socket_client.py
# -rw-r--r-- 1 root root 9070 Oct  7 10:03 socket_server.py
# drwxr-xr-x 3 root root 4096 Oct  7 10:03 train

# %%
# Check GPU status
# !nvidia-smi

# Check available memory
# !free -h

# Test PyTorch CUDA
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
# Out:
# Tue Oct  7 16:12:48 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       1.7Gi       249Mi       6.0Mi        10Gi        10Gi
# Swap:             0B          0B          0B
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# CUDA version: 12.6
# GPU: Tesla T4
# GPU Memory: 14.74 GB

# %%
# This prepares your dataset in F5-TTS format
# %cd /content/F5-TTS
# Out:
# /content/F5-TTS

# %%
"""
F5-TTS Fine-tuning Pipeline for Urdu Dataset
Run this after enabling GPU in Colab
"""

import os
import json

print("=" * 70)
print("F5-TTS Fine-tuning Setup for Urdu Dataset")
print("=" * 70)

# Step 1: Verify GPU
import torch
print("\n[1] GPU Check:")
print(f"   CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    print(f"   GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
else:
    print("   ⚠️  WARNING: GPU not detected!")
    print("   Go to Runtime → Change runtime type → Select GPU")

# Step 2: Dataset paths
DATASET_DIR = "/content/f5_tts_dataset"
TRAIN_METADATA = f"{DATASET_DIR}/train_metadata.csv"
VAL_METADATA = f"{DATASET_DIR}/val_metadata.csv"
CHECKPOINT_DIR = "/content/checkpoints"
EXPERIMENT_NAME = "urdu_tts_finetune"

# Create directories
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
os.makedirs(f"{CHECKPOINT_DIR}/logs", exist_ok=True)

print(f"\n[2] Dataset Info:")
print(f"   Dataset dir: {DATASET_DIR}")
print(f"   Train metadata: {TRAIN_METADATA}")
print(f"   Validation metadata: {VAL_METADATA}")
print(f"   Checkpoint dir: {CHECKPOINT_DIR}")

# Step 3: Prepare dataset in F5-TTS format
print(f"\n[3] Preparing dataset for F5-TTS...")

# F5-TTS expects a specific format, let's create it
import pandas as pd
import shutil

# Read our metadata
train_df = pd.read_csv(TRAIN_METADATA)
val_df = pd.read_csv(VAL_METADATA)

# Create F5-TTS compatible structure
f5_data_dir = "/content/f5_tts_formatted"
os.makedirs(f"{f5_data_dir}/wavs", exist_ok=True)

# Copy audio files and create metadata.list
with open(f"{f5_data_dir}/metadata.list", "w", encoding="utf-8") as f:
    for idx, row in train_df.iterrows():
        audio_src = os.path.join(DATASET_DIR, row['audio_path'])
        audio_filename = os.path.basename(row['audio_path'])
        audio_dst = f"{f5_data_dir}/wavs/{audio_filename}"

        # Create symlink instead of copying (saves space)
        if not os.path.exists(audio_dst):
            os.symlink(audio_src, audio_dst)

        # Write metadata in F5-TTS format: audio_path|text
        f.write(f"wavs/{audio_filename}|{row['text']}\n")

print(f"   ✓ Created F5-TTS formatted dataset at: {f5_data_dir}")
print(f"   ✓ Total training samples: {len(train_df)}")

# Step 4: Training configuration
print(f"\n[4] Training Configuration:")
config = {
    "exp_name": EXPERIMENT_NAME,
    "learning_rate": 7.5e-5,  # F5-TTS recommended
    "batch_size_per_gpu": 4,  # Reduce to 2 if OOM
    "batch_size_type": "frame",
    "max_samples": 64,
    "grad_accumulation_steps": 1,
    "max_grad_norm": 1.0,
    "epochs": 20,
    "num_warmup_updates": 2000,
    "save_per_updates": 1000,
    "log_per_updates": 10,
    "mixed_precision": "bf16",  # or "fp16"
    "dataset_name": "urdu_cv",
    "tokenizer": "pinyin",  # We'll use char tokenizer for Urdu
}

for key, value in config.items():
    print(f"   {key:25s}: {value}")

# Save config
config_path = f"{CHECKPOINT_DIR}/training_config.json"
with open(config_path, 'w') as f:
    json.dump(config, f, indent=2)

print(f"\n[5] ✓ Setup Complete!")
print(f"   Config saved: {config_path}")

# Step 5: Print training commands
print("\n" + "=" * 70)
print("TRAINING COMMANDS")
print("=" * 70)

print("""
# ============================================================
# METHOD 1: Using finetune_cli.py (RECOMMENDED)
# ============================================================
_


# ============================================================
# If you get OOM (Out of Memory) errors:
# ============================================================
# Reduce batch_size_per_gpu to 2 or 1
# Or reduce max_samples to 32
""")

print("\n" + "=" * 70)
print("MONITORING TRAINING")
print("=" * 70)
print("""
# View training logs in real-time
# !tail -f /content/checkpoints/logs/train.log

# Or check checkpoint directory
# !ls -lh /content/checkpoints/

# Monitor GPU usage
# !watch -n 1 nvidia-smi
""")

print("\n" + "=" * 70)
print("NEXT STEPS:")
print("=" * 70)
print("1. ⚠️  ENABLE GPU: Runtime → Change runtime type → GPU")
print("2. Run METHOD 1 command above to start training")
print("3. Training will take several hours depending on GPU")
print("4. Checkpoints saved to: /content/checkpoints/")
print("5. Monitor progress with: !tail -f /content/checkpoints/logs/train.log")
print("=" * 70)
# Out:
# ======================================================================
# F5-TTS Fine-tuning Setup for Urdu Dataset
# ======================================================================
#
# [1] GPU Check:
#    CUDA available: True
#    GPU: Tesla T4
#    GPU Memory: 14.74 GB
#
# [2] Dataset Info:
#    Dataset dir: /content/f5_tts_dataset
#    Train metadata: /content/f5_tts_dataset/train_metadata.csv
#    Validation metadata: /content/f5_tts_dataset/val_metadata.csv
#    Checkpoint dir: /content/checkpoints
#
# [3] Preparing dataset for F5-TTS...
#    ✓ Created F5-TTS formatted dataset at: /content/f5_tts_formatted
#    ✓ Total training samples: 4830
#
# [4] Training Configuration:
#    exp_name                 : urdu_tts_finetune
#    learning_rate            : 7.5e-05
#    batch_size_per_gpu       : 4
#    batch_size_type          : frame
#    max_samples              : 64
#    grad_accumulation_steps  : 1
#    max_grad_norm            : 1.0
#    epochs                   : 20
#    num_warmup_updates       : 2000
#    save_per_updates         : 1000
#    log_per_updates          : 10
#    mixed_precision          : bf16
#    dataset_name             : urdu_cv
#    tokenizer                : pinyin
#
# [5] ✓ Setup Complete!
#    Config saved: /content/checkpoints/training_config.json
#
# ======================================================================
# TRAINING COMMANDS
# ======================================================================
#
# # ============================================================
# # METHOD 1: Using finetune_cli.py (RECOMMENDED)
# # ============================================================
# _
#
#
# # ============================================================
# # If you get OOM (Out of Memory) errors:
# # ============================================================
# # Reduce batch_size_per_gpu to 2 or 1
# # Or reduce max_samples to 32
#
#
# ======================================================================
# MONITORING TRAINING
# ======================================================================
#
# # View training logs in real-time
# !tail -f /content/checkpoints/logs/train.log
#
# # Or check checkpoint directory
# !ls -lh /content/checkpoints/
#
# # Monitor GPU usage
# !watch -n 1 nvidia-smi
#
#
# ======================================================================
# NEXT STEPS:
# ======================================================================
# 1. ⚠️  ENABLE GPU: Runtime → Change runtime type → GPU
# 2. Run METHOD 1 command above to start training
# 3. Training will take several hours depending on GPU
# 4. Checkpoints saved to: /content/checkpoints/
# 5. Monitor progress with: !tail -f /content/checkpoints/logs/train.log
# ======================================================================

# %%
# %cd /content/F5-TTS
# !python src/f5_tts/train/finetune_cli.py --help
# Out:
# /content/F5-TTS
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# usage: finetune_cli.py [-h] [--exp_name {F5TTS_v1_Base,F5TTS_Base,E2TTS_Base}]
#                        [--dataset_name DATASET_NAME]
#                        [--learning_rate LEARNING_RATE]
#                        [--batch_size_per_gpu BATCH_SIZE_PER_GPU]
#                        [--batch_size_type {frame,sample}]
#                        [--max_samples MAX_SAMPLES]
#                        [--grad_accumulation_steps GRAD_ACCUMULATION_STEPS]
#                        [--max_grad_norm MAX_GRAD_NORM] [--epochs EPOCHS]
#                        [--num_warmup_updates NUM_WARMUP_UPDATES]
#                        [--save_per_updates SAVE_PER_UPDATES]
#                        [--keep_last_n_checkpoints KEEP_LAST_N_CHECKPOINTS]
#                        [--last_per_updates LAST_PER_UPDATES] [--finetune]
#                        [--pretrain PRETRAIN]
#                        [--tokenizer {pinyin,char,custom}]
#                        [--tokenizer_path TOKENIZER_PATH] [--log_samples]
#                        [--logger {None,wandb,tensorboard}] [--bnb_optimizer]
#
# Train CFM Model
#
# options:
#   -h, --help            show this help message and exit
#   --exp_name {F5TTS_v1_Base,F5TTS_Base,E2TTS_Base}
#                         Experiment name
#   --dataset_name DATASET_NAME
#                         Name of the dataset to use
#   --learning_rate LEARNING_RATE
#                         Learning rate for training
#   --batch_size_per_gpu BATCH_SIZE_PER_GPU
#                         Batch size per GPU
#   --batch_size_type {frame,sample}
#                         Batch size type
#   --max_samples MAX_SAMPLES
#                         Max sequences per batch
#   --grad_accumulation_steps GRAD_ACCUMULATION_STEPS
#                         Gradient accumulation steps
#   --max_grad_norm MAX_GRAD_NORM
#                         Max gradient norm for clipping
#   --epochs EPOCHS       Number of training epochs
#   --num_warmup_updates NUM_WARMUP_UPDATES
#                         Warmup updates
#   --save_per_updates SAVE_PER_UPDATES
#                         Save checkpoint every N updates
#   --keep_last_n_checkpoints KEEP_LAST_N_CHECKPOINTS
#                         -1 to keep all, 0 to not save intermediate, > 0 to
#                         keep last N checkpoints
#   --last_per_updates LAST_PER_UPDATES
#                         Save last checkpoint every N updates
#   --finetune            Use Finetune
#   --pretrain PRETRAIN   the path to the checkpoint
#   --tokenizer {pinyin,char,custom}
#                         Tokenizer type
#   --tokenizer_path TOKENIZER_PATH
#                         Path to custom tokenizer vocab file (only used if
#                         tokenizer = 'custom')
#   --log_samples         Log inferenced samples per ckpt save updates
#   --logger {None,wandb,tensorboard}
#                         logger
#   --bnb_optimizer       Use 8-bit Adam optimizer from bitsandbytes

# %%
# Check if F5-TTS expects the data in a specific location/format
# !ls -la src/f5_tts/train/datasets/
# !cat src/f5_tts/train/finetune_cli.py | grep -A 10 "data"
# Out:
# total 48
# drwxr-xr-x 2 root root  4096 Oct  7 21:11 .
# drwxr-xr-x 3 root root  4096 Oct  7 21:11 ..
# -rw-r--r-- 1 root root 10526 Oct  7 21:11 prepare_csv_wavs.py
# -rw-r--r-- 1 root root  7430 Oct  7 21:11 prepare_emilia.py
# -rw-r--r-- 1 root root  3245 Oct  7 21:11 prepare_emilia_v2.py
# -rw-r--r-- 1 root root  3181 Oct  7 21:11 prepare_libritts.py
# -rw-r--r-- 1 root root  2276 Oct  7 21:11 prepare_ljspeech.py
# -rw-r--r-- 1 root root  4580 Oct  7 21:11 prepare_wenetspeech4tts.py
# from f5_tts.model.dataset import load_dataset
# from f5_tts.model.utils import get_tokenizer
#
#
# # -------------------------- Dataset Settings --------------------------- #
# target_sample_rate = 24000
# n_mel_channels = 100
# hop_length = 256
# win_length = 1024
# n_fft = 1024
# mel_spec_type = "vocos"  # 'vocos' or 'bigvgan'
# --
#     parser.add_argument("--dataset_name", type=str, default="Emilia_ZH_EN", help="Name of the dataset to use")
#     parser.add_argument("--learning_rate", type=float, default=1e-5, help="Learning rate for training")
#     parser.add_argument("--batch_size_per_gpu", type=int, default=3200, help="Batch size per GPU")
#     parser.add_argument(
#         "--batch_size_type", type=str, default="frame", choices=["frame", "sample"], help="Batch size type"
#     )
#     parser.add_argument("--max_samples", type=int, default=64, help="Max sequences per batch")
#     parser.add_argument("--grad_accumulation_steps", type=int, default=1, help="Gradient accumulation steps")
#     parser.add_argument("--max_grad_norm", type=float, default=1.0, help="Max gradient norm for clipping")
#     parser.add_argument("--epochs", type=int, default=100, help="Number of training epochs")
#     parser.add_argument("--num_warmup_updates", type=int, default=20000, help="Warmup updates")
# --
#     checkpoint_path = str(files("f5_tts").joinpath(f"../../ckpts/{args.dataset_name}"))
#
#     # Model parameters based on experiment name
#
#     if args.exp_name == "F5TTS_v1_Base":
#         wandb_resume_id = None
#         model_cls = DiT
#         model_cfg = dict(
#             dim=1024,
#             depth=22,
#             heads=16,
# --
#         tokenizer_path = args.dataset_name
#
#     vocab_char_map, vocab_size = get_tokenizer(tokenizer_path, tokenizer)
#
#     print("\nvocab : ", vocab_size)
#     print("\nvocoder : ", mel_spec_type)
#
#     mel_spec_kwargs = dict(
#         n_fft=n_fft,
#         hop_length=hop_length,
#         win_length=win_length,
# --
#         wandb_project=args.dataset_name,
#         wandb_run_name=args.exp_name,
#         wandb_resume_id=wandb_resume_id,
#         log_samples=args.log_samples,
#         last_per_updates=args.last_per_updates,
#         bnb_optimizer=args.bnb_optimizer,
#     )
#
#     train_dataset = load_dataset(args.dataset_name, tokenizer, mel_spec_kwargs=mel_spec_kwargs)
#
#     trainer.train(
#         train_dataset,
#         resumable_with_seed=666,  # seed for shuffling dataset
#     )
#
#
# if __name__ == "__main__":
#     main()

# %%
# Check the training script to understand dataset loading
# !grep -n "dataset" src/f5_tts/train/finetune_cli.py | head -20
# Out:
# 9:from f5_tts.model.dataset import load_dataset
# 33:    parser.add_argument("--dataset_name", type=str, default="Emilia_ZH_EN", help="Name of the dataset to use")
# 84:    checkpoint_path = str(files("f5_tts").joinpath(f"../../ckpts/{args.dataset_name}"))
# 161:        tokenizer_path = args.dataset_name
# 197:        wandb_project=args.dataset_name,
# 205:    train_dataset = load_dataset(args.dataset_name, tokenizer, mel_spec_kwargs=mel_spec_kwargs)
# 208:        train_dataset,
# 209:        resumable_with_seed=666,  # seed for shuffling dataset

# %%
"""
Prepare Urdu dataset in F5-TTS expected format
"""

import os
import pandas as pd
import shutil
from pathlib import Path

print("=" * 70)
print("Preparing Urdu Dataset for F5-TTS Fine-tuning")
print("=" * 70)

# Source dataset
DATASET_DIR = "/content/f5_tts_dataset"
TRAIN_METADATA = f"{DATASET_DIR}/train_metadata.csv"
VAL_METADATA = f"{DATASET_DIR}/val_metadata.csv"

# F5-TTS expects data in a specific structure
# Let's create it under the F5-TTS data directory
F5_DATA_DIR = "/content/F5-TTS/data/urdu_cv"
os.makedirs(F5_DATA_DIR, exist_ok=True)
os.makedirs(f"{F5_DATA_DIR}/wavs", exist_ok=True)

print(f"\n[1] Loading metadata...")
train_df = pd.read_csv(TRAIN_METADATA)
val_df = pd.read_csv(VAL_METADATA)
print(f"   Train samples: {len(train_df)}")
print(f"   Val samples: {len(val_df)}")

# F5-TTS typically expects a metadata.list file with format:
# audio_path|transcription|speaker_id (optional)
print(f"\n[2] Creating metadata.list for training...")

train_count = 0
val_count = 0

# Create training metadata
with open(f"{F5_DATA_DIR}/metadata.list", "w", encoding="utf-8") as f:
    for idx, row in train_df.iterrows():
        # Source audio path
        audio_src = os.path.join(DATASET_DIR, row['audio_path'])

        if not os.path.exists(audio_src):
            continue

        # Target audio filename
        audio_filename = f"train_{idx:06d}.wav"
        audio_dst = f"{F5_DATA_DIR}/wavs/{audio_filename}"

        # Create symlink (saves disk space) or copy
        if not os.path.exists(audio_dst):
            try:
                os.symlink(audio_src, audio_dst)
            except:
                shutil.copy(audio_src, audio_dst)

        # Write metadata: audio_path|text
        text = row['text'].strip()
        f.write(f"wavs/{audio_filename}|{text}\n")
        train_count += 1

        if train_count % 500 == 0:
            print(f"   Processed {train_count}/{len(train_df)}...")

print(f"   ✓ Created training metadata: {train_count} samples")

# Create validation metadata (optional)
with open(f"{F5_DATA_DIR}/metadata_val.list", "w", encoding="utf-8") as f:
    for idx, row in val_df.iterrows():
        audio_src = os.path.join(DATASET_DIR, row['audio_path'])

        if not os.path.exists(audio_src):
            continue

        audio_filename = f"val_{idx:06d}.wav"
        audio_dst = f"{F5_DATA_DIR}/wavs/{audio_filename}"

        if not os.path.exists(audio_dst):
            try:
                os.symlink(audio_src, audio_dst)
            except:
                shutil.copy(audio_src, audio_dst)

        text = row['text'].strip()
        f.write(f"wavs/{audio_filename}|{text}\n")
        val_count += 1

print(f"   ✓ Created validation metadata: {val_count} samples")

# Verify the structure
print(f"\n[3] Verifying dataset structure...")
print(f"   Dataset directory: {F5_DATA_DIR}")
print(f"   Metadata file: {F5_DATA_DIR}/metadata.list")
print(f"   Audio directory: {F5_DATA_DIR}/wavs/")

# Check audio files
audio_files = list(Path(f"{F5_DATA_DIR}/wavs").glob("*.wav"))
print(f"   Total audio files: {len(audio_files)}")

# Display sample metadata
print(f"\n[4] Sample metadata (first 3 lines):")
with open(f"{F5_DATA_DIR}/metadata.list", "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        if i < 3:
            print(f"   {line.strip()}")

print("\n" + "=" * 70)
print("✓ Dataset preparation complete!")
print("=" * 70)
print(f"\nYour dataset is ready at: {F5_DATA_DIR}")
print(f"You can now start fine-tuning with the dataset_name: urdu_cv")

# Summary
print("\n" + "=" * 70)
print("DATASET SUMMARY")
print("=" * 70)
print(f"Training samples: {train_count}")
print(f"Validation samples: {val_count}")
# Calculate duration if available
if 'duration' in train_df.columns:
    print(f"Total duration: ~{train_df['duration'].sum()/3600:.2f} hours (estimated)")
print(f"Dataset location: {F5_DATA_DIR}")
print("=" * 70)
# Out:
# ======================================================================
# Preparing Urdu Dataset for F5-TTS Fine-tuning
# ======================================================================
#
# [1] Loading metadata...
#    Train samples: 4830
#    Val samples: 537
#
# [2] Creating metadata.list for training...
#    Processed 500/4830...
#    Processed 1000/4830...
#    Processed 1500/4830...
#    Processed 2000/4830...
#    Processed 2500/4830...
#    Processed 3000/4830...
#    Processed 3500/4830...
#    Processed 4000/4830...
#    Processed 4500/4830...
#    ✓ Created training metadata: 4830 samples
#    ✓ Created validation metadata: 537 samples
#
# [3] Verifying dataset structure...
#    Dataset directory: /content/F5-TTS/data/urdu_cv
#    Metadata file: /content/F5-TTS/data/urdu_cv/metadata.list
#    Audio directory: /content/F5-TTS/data/urdu_cv/wavs/
#    Total audio files: 5367
#
# [4] Sample metadata (first 3 lines):
#    wavs/train_000000.wav|میں آپ کو حوالات میں بند کروا دوں گا
#    wavs/train_000001.wav|اٹھارہویں صدی میں قائم ہونے والے کوئٹہ کو آب و ہوا ماحول اور خوبصورتی کی وجہ سے انگریز لٹل لندن کہتے تھے
#    wavs/train_000002.wav|کامن ویلتھ گیمزپاکستانی ریسلر نے کانسی کا تمغہ جیت لیا
#
# ======================================================================
# ✓ Dataset preparation complete!
# ======================================================================
#
# Your dataset is ready at: /content/F5-TTS/data/urdu_cv
# You can now start fine-tuning with the dataset_name: urdu_cv
#
# ======================================================================
# DATASET SUMMARY
# ======================================================================
# Training samples: 4830
# Validation samples: 537
# Dataset location: /content/F5-TTS/data/urdu_cv
# ======================================================================

# %%
metadata_file = "/content/F5-TTS/data/urdu_cv/metadata.list"
vocab_output_path = "/content/F5-TTS/data/urdu_cv_char/vocab.txt"

unique_chars = set()
with open(metadata_file, "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split("|")
        if len(parts) == 2:
            text = parts[1]
            unique_chars.update(text)

# Remove space if accidentally in set, we will add it explicitly as first line
unique_chars.discard(' ')

# Sort remaining characters
unique_chars = sorted(unique_chars)

import os
os.makedirs(os.path.dirname(vocab_output_path), exist_ok=True)

with open(vocab_output_path, "w", encoding="utf-8") as f:
    # Write space as index 0
    f.write(" \n")
    # Write all other chars
    for ch in unique_chars:
        f.write(ch + "\n")

print(f"Vocabulary file created with space as the first token at: {vocab_output_path}")
# Out:
# Vocabulary file created with space as the first token at: /content/F5-TTS/data/urdu_cv_char/vocab.txt

# %%
from datasets.arrow_writer import ArrowWriter
from tqdm import tqdm
from pathlib import Path
import json
import os

metadata_path = "/content/F5-TTS/data/urdu_cv/metadata.list"
audio_base_dir = "/content/F5-TTS/data/urdu_cv/wavs"
output_dir = "/content/F5-TTS/data/urdu_cv_char"

def read_metadata(metadata_file):
    audio_text_pairs = []
    with open(metadata_file, "r", encoding="utf-8") as file:
        for line in file:
            parts = line.strip().split("|")
            if len(parts) == 2:
                audio_path = os.path.join(audio_base_dir, parts[0])
                text = parts[1]
                if os.path.isfile(audio_path):
                    audio_text_pairs.append({"audio_path": audio_path, "text": text})
    return audio_text_pairs

def save_prepared_dataset(dataset_entries, output_folder):
    out_dir = Path(output_folder)
    out_dir.mkdir(parents=True, exist_ok=True)
    raw_arrow_path = out_dir / "raw.arrow"
    duration_list = []

    # Writing raw.arrow with ArrowWriter
    with ArrowWriter(path=str(raw_arrow_path), writer_batch_size=1) as writer:
        for entry in tqdm(dataset_entries, desc="Writing raw.arrow"):
            writer.write(entry)
            # Duration is optional, skipping for now

    # Save vocab.txt, add space as index 0
    vocab_set = set()
    for entry in dataset_entries:
        vocab_set.update(set(entry["text"]))
    if ' ' in vocab_set:
        vocab_set.remove(' ')
    vocab = [' '] + sorted(vocab_set)

    vocab_path = out_dir / "vocab.txt"
    with open(vocab_path, "w", encoding="utf-8") as f:
        for token in vocab:
            f.write(token + "\n")

    print(f"Saved raw.arrow and vocab.txt to {output_folder}")

# Run preparation
metadata_entries = read_metadata(metadata_path)
save_prepared_dataset(metadata_entries, output_dir)
# Out:
# Writing raw.arrow: 0it [00:00, ?it/s]
# Saved raw.arrow and vocab.txt to /content/F5-TTS/data/urdu_cv_char

# %%
# Run the dataset preparation
# %cd /content

# Execute the preparation script (from the artifact above)
# Copy and paste the artifact code, or run it directly
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create backup directory in Drive
import os
os.makedirs('/content/drive/MyDrive/F5-TTS-Checkpoints', exist_ok=True)

# Make checkpoints save directly to Drive
# !rm -rf /content/F5-TTS/ckpts
# !ln -s /content/drive/MyDrive/F5-TTS-Checkpoints /content/F5-TTS/ckpts

print("✓ Checkpoints will now save directly to Google Drive!")
print("Location: /content/drive/MyDrive/F5-TTS-Checkpoints")
# Out:
# Mounted at /content/drive
# ✓ Checkpoints will now save directly to Google Drive!
# Location: /content/drive/MyDrive/F5-TTS-Checkpoints

# %%
# @title
# Quick fix - create symlink with _char suffix
import os
os.makedirs("/content/F5-TTS/data/urdu_cv_char", exist_ok=True)
# !ln -sf /content/F5-TTS/data/urdu_cv/raw.arrow /content/F5-TTS/data/urdu_cv_char/raw.arrow
# !ln -sf /content/F5-TTS/data/urdu_cv/vocab.txt /content/F5-TTS/data/urdu_cv_char/vocab.txt
# !ln -sf /content/F5-TTS/data/urdu_cv/duration.json /content/F5-TTS/data/urdu_cv_char/duration.json
print("✓ Fixed! Now start training.")
# Out:
# ✓ Fixed! Now start training.

# %%
# @title
# Quick patch for the trainer bug
import os

trainer_file = "/content/F5-TTS/src/f5_tts/model/trainer.py"

# Read the file
with open(trainer_file, 'r') as f:
    content = f.read()

# Add a check to prevent division by zero
original_line = "skipped_epoch = int(start_step // orig_epoch_step)"
patched_line = "skipped_epoch = int(start_step // orig_epoch_step) if orig_epoch_step > 0 else 0"

if original_line in content:
    content = content.replace(original_line, patched_line)
    with open(trainer_file, 'w') as f:
        f.write(content)
    print("✓ Trainer patched! Now try training again.")
else:
    print("Line not found or already patched.")
# Out:
# ✓ Trainer patched! Now try training again.

# %%
# First, clear GPU memory
import torch
torch.cuda.empty_cache()

# Then restart training with smaller batch size
# %cd /content/F5-TTS

# !python src/f5_tts/train/finetune_cli.py \
    --exp_name F5TTS_Base \
    --dataset_name urdu_cv \
    --learning_rate 7.5e-5 \
    --batch_size_per_gpu 4 \
    --batch_size_type sample \
    --grad_accumulation_steps 4 \
    --max_grad_norm 1.0 \
    --epochs 20 \
    --num_warmup_updates 1000 \
    --save_per_updates 500 \
    --last_per_updates 250 \
    --finetune \
    --tokenizer char \
    --log_samples \
    --logger tensorboard
# Out:
# /content/F5-TTS
# copy checkpoint for finetune
#
# vocab :  2545
#
# vocoder :  vocos
# 2025-10-07 22:09:04.135205: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759874944.169886   25178 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759874944.182022   25178 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759874944.207874   25178 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759874944.207910   25178 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759874944.207916   25178 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759874944.207923   25178 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-07 22:09:04.215959: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using logger: tensorboard
# Gradient accumulation checkpointing with per_updates now, old logic per_steps used with before f992c4e
# Loading dataset ...
# Download Vocos from huggingface charactr/vocos-mel-24khz
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch 1/20:   0% 0/302 [00:00<?, ?update/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Epoch 1/20:  83% 250/302 [18:01<04:01,  4.64s/update, loss=0.636, update=250]Saved last checkpoint at update 250
# Epoch 1/20: 100% 302/302 [23:02<00:00,  3.81s/update, loss=0.901, update=302]
# Epoch 1/20: 100% 302/302 [23:02<00:00,  4.58s/update, loss=0.901, update=302]
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
#
# Epoch 2/20:   0% 1/302 [00:09<48:45,  9.72s/update]
# Epoch 2/20:   0% 1/302 [00:09<48:45,  9.72s/update, loss=0.662, update=303]
# Epoch 2/20:   1% 2/302 [00:14<32:37,  6.52s/update, loss=0.662, update=303]
# Epoch 2/20:   1% 2/302 [00:14<32:37,  6.52s/update, loss=0.706, update=304]
# Epoch 2/20:   1% 3/302 [00:18<27:54,  5.60s/update, loss=0.706, update=304]
# Epoch 2/20:   1% 3/302 [00:18<27:54,  5.60s/update, loss=0.769, update=305]
# Epoch 2/20:   1% 4/302 [00:23<26:08,  5.26s/update, loss=0.769, update=305]
# Epoch 2/20:   1% 4/302 [00:23<26:08,  5.26s/update, loss=0.613, update=306]
# Epoch 2/20:   2% 5/302 [00:27<24:30,  4.95s/update, loss=0.613, update=306]
# Epoch 2/20:   2% 5/302 [00:27<24:30,  4.95s/update, loss=0.88, update=307]
# Epoch 2/20:   2% 6/302 [00:32<24:01,  4.87s/update, loss=0.88, update=307]
# Epoch 2/20:   2% 6/302 [00:32<24:01,  4.87s/update, loss=0.675, update=308]
# Epoch 2/20:   2% 7/302 [00:35<21:24,  4.35s/update, loss=0.675, update=308]
# Epoch 2/20:   2% 7/302 [00:35<21:24,  4.35s/update, loss=0.679, update=309]
# Epoch 2/20:   3% 8/302 [00:40<21:27,  4.38s/update, loss=0.679, update=309]
# Epoch 2/20:   3% 8/302 [00:40<21:27,  4.38s/update, loss=0.565, update=310]
# Epoch 2/20:   3% 9/302 [00:43<20:04,  4.11s/update, loss=0.565, update=310]
# Epoch 2/20:   3% 9/302 [00:43<20:04,  4.11s/update, loss=0.951, update=311]
# Epoch 2/20:   3% 10/302 [00:47<19:01,  3.91s/update, loss=0.951, update=311]
# Epoch 2/20:   3% 10/302 [00:47<19:01,  3.91s/update, loss=0.854, update=312]
# Epoch 2/20:   4% 11/302 [00:51<19:10,  3.95s/update, loss=0.854, update=312]
# Epoch 2/20:   4% 11/302 [00:51<19:10,  3.95s/update, loss=0.564, update=313]
# Epoch 2/20:   4% 12/302 [00:56<20:46,  4.30s/update, loss=0.564, update=313]
# Epoch 2/20:   4% 12/302 [00:56<20:46,  4.30s/update, loss=0.772, update=314]
# Epoch 2/20:   4% 13/302 [01:00<20:38,  4.28s/update, loss=0.772, update=314]
# Epoch 2/20:   4% 13/302 [01:00<20:38,  4.28s/update, loss=0.716, update=315]
# Epoch 2/20:   5% 14/302 [01:04<19:44,  4.11s/update, loss=0.716, update=315]
# Epoch 2/20:   5% 14/302 [01:04<19:44,  4.11s/update, loss=0.934, update=316]
# Epoch 2/20:   5% 15/302 [01:08<19:42,  4.12s/update, loss=0.934, update=316]
# Epoch 2/20:   5% 15/302 [01:08<19:42,  4.12s/update, loss=0.579, update=317]
# Epoch 2/20:   5% 16/302 [01:12<20:10,  4.23s/update, loss=0.579, update=317]
# Epoch 2/20:   5% 16/302 [01:12<20:10,  4.23s/update, loss=0.79, update=318]
# Epoch 2/20:   6% 17/302 [01:17<21:08,  4.45s/update, loss=0.79, update=318]
# Epoch 2/20:   6% 17/302 [01:17<21:08,  4.45s/update, loss=0.82, update=319]
# Epoch 2/20:   6% 18/302 [01:21<20:04,  4.24s/update, loss=0.82, update=319]
# Epoch 2/20:   6% 18/302 [01:21<20:04,  4.24s/update, loss=0.675, update=320]
# Epoch 2/20:   6% 19/302 [01:26<20:36,  4.37s/update, loss=0.675, update=320]
# Epoch 2/20:   6% 19/302 [01:26<20:36,  4.37s/update, loss=0.791, update=321]
# Epoch 2/20:   7% 20/302 [01:29<18:49,  4.01s/update, loss=0.791, update=321]
# Epoch 2/20:   7% 20/302 [01:29<18:49,  4.01s/update, loss=0.708, update=322]
# Epoch 2/20:   7% 21/302 [01:32<17:51,  3.81s/update, loss=0.708, update=322]
# Epoch 2/20:   7% 21/302 [01:32<17:51,  3.81s/update, loss=0.72, update=323]
# Epoch 2/20:   7% 22/302 [01:37<19:01,  4.08s/update, loss=0.72, update=323]
# Epoch 2/20:   7% 22/302 [01:37<19:01,  4.08s/update, loss=0.782, update=324]
# Epoch 2/20:   8% 23/302 [01:42<20:28,  4.40s/update, loss=0.782, update=324]
# Epoch 2/20:   8% 23/302 [01:42<20:28,  4.40s/update, loss=0.63, update=325]
# Epoch 2/20:   8% 24/302 [01:47<21:03,  4.54s/update, loss=0.63, update=325]
# Epoch 2/20:   8% 24/302 [01:47<21:03,  4.54s/update, loss=0.724, update=326]
# Epoch 2/20:   8% 25/302 [01:51<20:36,  4.46s/update, loss=0.724, update=326]
# Epoch 2/20:   8% 25/302 [01:51<20:36,  4.46s/update, loss=0.697, update=327]
# Epoch 2/20:   9% 26/302 [01:56<20:50,  4.53s/update, loss=0.697, update=327]
# Epoch 2/20:   9% 26/302 [01:56<20:50,  4.53s/update, loss=0.736, update=328]
# Epoch 2/20:   9% 27/302 [02:01<21:25,  4.67s/update, loss=0.736, update=328]
# Epoch 2/20:   9% 27/302 [02:01<21:25,  4.67s/update, loss=0.618, update=329]
# Epoch 2/20:   9% 28/302 [02:05<21:13,  4.65s/update, loss=0.618, update=329]
# Epoch 2/20:   9% 28/302 [02:05<21:13,  4.65s/update, loss=0.979, update=330]
# Epoch 2/20:  10% 29/302 [02:09<19:39,  4.32s/update, loss=0.979, update=330]
# Epoch 2/20:  10% 29/302 [02:09<19:39,  4.32s/update, loss=1.54, update=331]
# Epoch 2/20:  10% 30/302 [02:13<19:42,  4.35s/update, loss=1.54, update=331]
# Epoch 2/20:  10% 30/302 [02:13<19:42,  4.35s/update, loss=0.977, update=332]
# Epoch 2/20:  10% 31/302 [02:18<19:41,  4.36s/update, loss=0.977, update=332]
# Epoch 2/20:  10% 31/302 [02:18<19:41,  4.36s/update, loss=0.658, update=333]
# Epoch 2/20:  11% 32/302 [02:23<20:22,  4.53s/update, loss=0.658, update=333]
# Epoch 2/20:  11% 32/302 [02:23<20:22,  4.53s/update, loss=0.767, update=334]
# Epoch 2/20:  11% 33/302 [02:27<20:10,  4.50s/update, loss=0.767, update=334]
# Epoch 2/20:  11% 33/302 [02:27<20:10,  4.50s/update, loss=0.756, update=335]
# Epoch 2/20:  11% 34/302 [02:31<19:43,  4.42s/update, loss=0.756, update=335]
# Epoch 2/20:  11% 34/302 [02:31<19:43,  4.42s/update, loss=1.07, update=336]
# Epoch 2/20:  12% 35/302 [02:36<19:48,  4.45s/update, loss=1.07, update=336]
# Epoch 2/20:  12% 35/302 [02:36<19:48,  4.45s/update, loss=0.648, update=337]
# Epoch 2/20:  12% 36/302 [02:40<18:58,  4.28s/update, loss=0.648, update=337]
# Epoch 2/20:  12% 36/302 [02:40<18:58,  4.28s/update, loss=0.575, update=338]
# Epoch 2/20:  12% 37/302 [02:44<18:58,  4.30s/update, loss=0.575, update=338]
# Epoch 2/20:  12% 37/302 [02:44<18:58,  4.30s/update, loss=0.687, update=339]
# Epoch 2/20:  13% 38/302 [02:48<18:44,  4.26s/update, loss=0.687, update=339]
# Epoch 2/20:  13% 38/302 [02:48<18:44,  4.26s/update, loss=0.653, update=340]
# Epoch 2/20:  13% 39/302 [02:52<18:22,  4.19s/update, loss=0.653, update=340]
# Epoch 2/20:  13% 39/302 [02:52<18:22,  4.19s/update, loss=0.686, update=341]
# Epoch 2/20:  13% 40/302 [02:57<18:42,  4.28s/update, loss=0.686, update=341]
# Epoch 2/20:  13% 40/302 [02:57<18:42,  4.28s/update, loss=0.567, update=342]
# Epoch 2/20:  14% 41/302 [03:01<19:03,  4.38s/update, loss=0.567, update=342]
# Epoch 2/20:  14% 41/302 [03:01<19:03,  4.38s/update, loss=0.792, update=343]
# Epoch 2/20:  14% 42/302 [03:06<19:29,  4.50s/update, loss=0.792, update=343]
# Epoch 2/20:  14% 42/302 [03:06<19:29,  4.50s/update, loss=0.753, update=344]
# Epoch 2/20:  14% 43/302 [03:10<19:03,  4.42s/update, loss=0.753, update=344]
# Epoch 2/20:  14% 43/302 [03:10<19:03,  4.42s/update, loss=0.997, update=345]
# Epoch 2/20:  15% 44/302 [03:14<17:53,  4.16s/update, loss=0.997, update=345]
# Epoch 2/20:  15% 44/302 [03:14<17:53,  4.16s/update, loss=1.74, update=346]
# Epoch 2/20:  15% 45/302 [03:18<17:59,  4.20s/update, loss=1.74, update=346]
# Epoch 2/20:  15% 45/302 [03:18<17:59,  4.20s/update, loss=0.757, update=347]
# Epoch 2/20:  15% 46/302 [03:23<18:45,  4.39s/update, loss=0.757, update=347]
# Epoch 2/20:  15% 46/302 [03:23<18:45,  4.39s/update, loss=0.983, update=348]
# Epoch 2/20:  16% 47/302 [03:28<19:19,  4.55s/update, loss=0.983, update=348]
# Epoch 2/20:  16% 47/302 [03:28<19:19,  4.55s/update, loss=0.64, update=349]
# Epoch 2/20:  16% 48/302 [03:33<20:00,  4.73s/update, loss=0.64, update=349]
# Epoch 2/20:  16% 48/302 [03:33<20:00,  4.73s/update, loss=0.676, update=350]
# Epoch 2/20:  16% 49/302 [03:38<20:26,  4.85s/update, loss=0.676, update=350]
# Epoch 2/20:  16% 49/302 [03:38<20:26,  4.85s/update, loss=0.639, update=351]
# Epoch 2/20:  17% 50/302 [03:42<19:12,  4.58s/update, loss=0.639, update=351]
# Epoch 2/20:  17% 50/302 [03:42<19:12,  4.58s/update, loss=0.707, update=352]
# Epoch 2/20:  17% 51/302 [03:46<18:38,  4.46s/update, loss=0.707, update=352]
# Epoch 2/20:  17% 51/302 [03:46<18:38,  4.46s/update, loss=0.714, update=353]
# Epoch 2/20:  17% 52/302 [03:50<17:37,  4.23s/update, loss=0.714, update=353]
# Epoch 2/20:  17% 52/302 [03:50<17:37,  4.23s/update, loss=0.936, update=354]
# Epoch 2/20:  18% 53/302 [03:54<16:49,  4.05s/update, loss=0.936, update=354]
# Epoch 2/20:  18% 53/302 [03:54<16:49,  4.05s/update, loss=0.772, update=355]
# Epoch 2/20:  18% 54/302 [03:58<16:47,  4.06s/update, loss=0.772, update=355]
# Epoch 2/20:  18% 54/302 [03:58<16:47,  4.06s/update, loss=0.599, update=356]
# Epoch 2/20:  18% 55/302 [04:03<17:36,  4.28s/update, loss=0.599, update=356]
# Epoch 2/20:  18% 55/302 [04:03<17:36,  4.28s/update, loss=0.64, update=357]
# Epoch 2/20:  19% 56/302 [04:07<17:55,  4.37s/update, loss=0.64, update=357]
# Epoch 2/20:  19% 56/302 [04:07<17:55,  4.37s/update, loss=0.593, update=358]
# Epoch 2/20:  19% 57/302 [04:12<18:30,  4.53s/update, loss=0.593, update=358]
# Epoch 2/20:  19% 57/302 [04:12<18:30,  4.53s/update, loss=0.936, update=359]
# Epoch 2/20:  19% 58/302 [04:17<18:16,  4.49s/update, loss=0.936, update=359]
# Epoch 2/20:  19% 58/302 [04:17<18:16,  4.49s/update, loss=0.858, update=360]
# Epoch 2/20:  20% 59/302 [04:21<17:50,  4.41s/update, loss=0.858, update=360]
# Epoch 2/20:  20% 59/302 [04:21<17:50,  4.41s/update, loss=0.983, update=361]
# Epoch 2/20:  20% 60/302 [04:25<17:56,  4.45s/update, loss=0.983, update=361]
# Epoch 2/20:  20% 60/302 [04:25<17:56,  4.45s/update, loss=0.805, update=362]
# Epoch 2/20:  20% 61/302 [04:30<18:00,  4.48s/update, loss=0.805, update=362]
# Epoch 2/20:  20% 61/302 [04:30<18:00,  4.48s/update, loss=0.603, update=363]
# Epoch 2/20:  21% 62/302 [04:33<16:40,  4.17s/update, loss=0.603, update=363]
# Epoch 2/20:  21% 62/302 [04:33<16:40,  4.17s/update, loss=0.625, update=364]
# Epoch 2/20:  21% 63/302 [04:38<17:13,  4.32s/update, loss=0.625, update=364]
# Epoch 2/20:  21% 63/302 [04:38<17:13,  4.32s/update, loss=0.679, update=365]
# Epoch 2/20:  21% 64/302 [04:42<16:33,  4.17s/update, loss=0.679, update=365]
# Epoch 2/20:  21% 64/302 [04:42<16:33,  4.17s/update, loss=0.985, update=366]
# Epoch 2/20:  22% 65/302 [04:46<16:33,  4.19s/update, loss=0.985, update=366]
# Epoch 2/20:  22% 65/302 [04:46<16:33,  4.19s/update, loss=0.714, update=367]
# Epoch 2/20:  22% 66/302 [04:51<17:25,  4.43s/update, loss=0.714, update=367]
# Epoch 2/20:  22% 66/302 [04:51<17:25,  4.43s/update, loss=0.649, update=368]
# Epoch 2/20:  22% 67/302 [04:55<16:28,  4.21s/update, loss=0.649, update=368]
# ...
# Epoch 4/20:  20% 59/302 [04:17<17:25,  4.30s/update, loss=1.17, update=965]
# Epoch 4/20:  20% 60/302 [04:21<16:55,  4.20s/update, loss=1.17, update=965]
# Epoch 4/20:  20% 60/302 [04:21<16:55,  4.20s/update, loss=0.951, update=966]
# Epoch 4/20:  20% 61/302 [04:26<16:54,  4.21s/update, loss=0.951, update=966]
# Epoch 4/20:  20% 61/302 [04:26<16:54,  4.21s/update, loss=0.701, update=967]
# Epoch 4/20:  21% 62/302 [04:30<17:13,  4.30s/update, loss=0.701, update=967]
# Epoch 4/20:  21% 62/302 [04:30<17:13,  4.30s/update, loss=0.664, update=968]
# Epoch 4/20:  21% 63/302 [04:34<16:39,  4.18s/update, loss=0.664, update=968]
# Epoch 4/20:  21% 63/302 [04:34<16:39,  4.18s/update, loss=0.696, update=969]
# Epoch 4/20:  21% 64/302 [04:38<16:51,  4.25s/update, loss=0.696, update=969]
# Epoch 4/20:  21% 64/302 [04:38<16:51,  4.25s/update, loss=0.776, update=970]
# Epoch 4/20:  22% 65/302 [04:43<17:02,  4.31s/update, loss=0.776, update=970]
# Epoch 4/20:  22% 65/302 [04:43<17:02,  4.31s/update, loss=0.581, update=971]
# Epoch 4/20:  22% 66/302 [04:47<16:19,  4.15s/update, loss=0.581, update=971]
# Epoch 4/20:  22% 66/302 [04:47<16:19,  4.15s/update, loss=0.694, update=972]
# Epoch 4/20:  22% 67/302 [04:51<16:08,  4.12s/update, loss=0.694, update=972]
# Epoch 4/20:  22% 67/302 [04:51<16:08,  4.12s/update, loss=0.648, update=973]
# Epoch 4/20:  23% 68/302 [04:57<17:57,  4.60s/update, loss=0.648, update=973]
# Epoch 4/20:  23% 68/302 [04:57<17:57,  4.60s/update, loss=0.689, update=974]
# Epoch 4/20:  23% 69/302 [05:01<17:32,  4.52s/update, loss=0.689, update=974]
# Epoch 4/20:  23% 69/302 [05:01<17:32,  4.52s/update, loss=0.739, update=975]
# Epoch 4/20:  23% 70/302 [05:05<17:30,  4.53s/update, loss=0.739, update=975]
# Epoch 4/20:  23% 70/302 [05:05<17:30,  4.53s/update, loss=0.667, update=976]
# Epoch 4/20:  24% 71/302 [05:10<17:21,  4.51s/update, loss=0.667, update=976]
# Epoch 4/20:  24% 71/302 [05:10<17:21,  4.51s/update, loss=0.721, update=977]
# Epoch 4/20:  24% 72/302 [05:14<16:28,  4.30s/update, loss=0.721, update=977]
# Epoch 4/20:  24% 72/302 [05:14<16:28,  4.30s/update, loss=0.811, update=978]
# Epoch 4/20:  24% 73/302 [05:18<16:40,  4.37s/update, loss=0.811, update=978]
# Epoch 4/20:  24% 73/302 [05:18<16:40,  4.37s/update, loss=0.635, update=979]
# Epoch 4/20:  25% 74/302 [05:23<17:27,  4.59s/update, loss=0.635, update=979]
# Epoch 4/20:  25% 74/302 [05:23<17:27,  4.59s/update, loss=0.854, update=980]
# Epoch 4/20:  25% 75/302 [05:27<16:48,  4.44s/update, loss=0.854, update=980]
# Epoch 4/20:  25% 75/302 [05:27<16:48,  4.44s/update, loss=0.964, update=981]
# Epoch 4/20:  25% 76/302 [05:32<17:07,  4.55s/update, loss=0.964, update=981]
# Epoch 4/20:  25% 76/302 [05:32<17:07,  4.55s/update, loss=0.673, update=982]
# Epoch 4/20:  25% 77/302 [05:36<16:05,  4.29s/update, loss=0.673, update=982]
# Epoch 4/20:  25% 77/302 [05:36<16:05,  4.29s/update, loss=0.542, update=983]
# Epoch 4/20:  26% 78/302 [05:40<15:31,  4.16s/update, loss=0.542, update=983]
# Epoch 4/20:  26% 78/302 [05:40<15:31,  4.16s/update, loss=0.693, update=984]
# Epoch 4/20:  26% 79/302 [05:43<14:58,  4.03s/update, loss=0.693, update=984]
# Epoch 4/20:  26% 79/302 [05:43<14:58,  4.03s/update, loss=0.7, update=985]
# Epoch 4/20:  26% 80/302 [05:48<15:49,  4.28s/update, loss=0.7, update=985]
# Epoch 4/20:  26% 80/302 [05:48<15:49,  4.28s/update, loss=0.791, update=986]
# Epoch 4/20:  27% 81/302 [05:52<14:52,  4.04s/update, loss=0.791, update=986]
# Epoch 4/20:  27% 81/302 [05:52<14:52,  4.04s/update, loss=0.798, update=987]
# Epoch 4/20:  27% 82/302 [05:55<14:12,  3.88s/update, loss=0.798, update=987]
# Epoch 4/20:  27% 82/302 [05:55<14:12,  3.88s/update, loss=0.641, update=988]
# Epoch 4/20:  27% 83/302 [06:00<15:12,  4.16s/update, loss=0.641, update=988]
# Epoch 4/20:  27% 83/302 [06:00<15:12,  4.16s/update, loss=1.57, update=989]
# Epoch 4/20:  28% 84/302 [06:04<14:38,  4.03s/update, loss=1.57, update=989]
# Epoch 4/20:  28% 84/302 [06:04<14:38,  4.03s/update, loss=0.694, update=990]
# Epoch 4/20:  28% 85/302 [06:08<14:35,  4.04s/update, loss=0.694, update=990]
# Epoch 4/20:  28% 85/302 [06:08<14:35,  4.04s/update, loss=0.808, update=991]
# Epoch 4/20:  28% 86/302 [06:12<14:35,  4.05s/update, loss=0.808, update=991]
# Epoch 4/20:  28% 86/302 [06:12<14:35,  4.05s/update, loss=0.758, update=992]
# Epoch 4/20:  29% 87/302 [06:17<15:43,  4.39s/update, loss=0.758, update=992]
# Epoch 4/20:  29% 87/302 [06:17<15:43,  4.39s/update, loss=0.808, update=993]
# Epoch 4/20:  29% 88/302 [06:22<16:12,  4.54s/update, loss=0.808, update=993]
# Epoch 4/20:  29% 88/302 [06:22<16:12,  4.54s/update, loss=0.788, update=994]
# Epoch 4/20:  29% 89/302 [06:26<15:50,  4.46s/update, loss=0.788, update=994]
# Epoch 4/20:  29% 89/302 [06:26<15:50,  4.46s/update, loss=0.744, update=995]
# Epoch 4/20:  30% 90/302 [06:30<15:10,  4.29s/update, loss=0.744, update=995]
# Epoch 4/20:  30% 90/302 [06:30<15:10,  4.29s/update, loss=0.785, update=996]
# Epoch 4/20:  30% 91/302 [06:35<15:39,  4.45s/update, loss=0.785, update=996]
# Epoch 4/20:  30% 91/302 [06:35<15:39,  4.45s/update, loss=0.931, update=997]
# Epoch 4/20:  30% 92/302 [06:39<15:11,  4.34s/update, loss=0.931, update=997]
# Epoch 4/20:  30% 92/302 [06:39<15:11,  4.34s/update, loss=0.664, update=998]
# Epoch 4/20:  31% 93/302 [06:43<14:41,  4.22s/update, loss=0.664, update=998]
# Epoch 4/20:  31% 93/302 [06:43<14:41,  4.22s/update, loss=0.66, update=999]
# Epoch 4/20:  31% 94/302 [06:48<15:02,  4.34s/update, loss=0.66, update=999]
# Epoch 4/20:  31% 94/302 [06:48<15:02,  4.34s/update, loss=0.713, update=1000]Saved last checkpoint at update 1000
#
# Epoch 4/20:  31% 95/302 [12:01<5:34:57, 97.09s/update, loss=0.713, update=1000]
# Epoch 4/20:  31% 95/302 [12:01<5:34:57, 97.09s/update, loss=0.721, update=1001]
# Epoch 4/20:  32% 96/302 [12:06<3:57:47, 69.26s/update, loss=0.721, update=1001]
# Epoch 4/20:  32% 96/302 [12:06<3:57:47, 69.26s/update, loss=0.684, update=1002]
# Epoch 4/20:  32% 97/302 [12:10<2:50:40, 49.95s/update, loss=0.684, update=1002]
# Epoch 4/20:  32% 97/302 [12:10<2:50:40, 49.95s/update, loss=0.887, update=1003]
# Epoch 4/20:  32% 98/302 [12:15<2:03:05, 36.20s/update, loss=0.887, update=1003]
# Epoch 4/20:  32% 98/302 [12:15<2:03:05, 36.20s/update, loss=0.613, update=1004]
# Epoch 4/20:  33% 99/302 [12:18<1:29:17, 26.39s/update, loss=0.613, update=1004]
# Epoch 4/20:  33% 99/302 [12:18<1:29:17, 26.39s/update, loss=0.744, update=1005]
# Epoch 4/20:  33% 100/302 [12:22<1:06:12, 19.67s/update, loss=0.744, update=1005]
# Epoch 4/20:  33% 100/302 [12:22<1:06:12, 19.67s/update, loss=0.836, update=1006]
# Epoch 4/20:  33% 101/302 [12:26<49:52, 14.89s/update, loss=0.836, update=1006]
# Epoch 4/20:  33% 101/302 [12:26<49:52, 14.89s/update, loss=0.753, update=1007]
# Epoch 4/20:  34% 102/302 [12:29<38:11, 11.46s/update, loss=0.753, update=1007]
# Epoch 4/20:  34% 102/302 [12:29<38:11, 11.46s/update, loss=0.726, update=1008]
# Epoch 4/20:  34% 103/302 [12:34<31:22,  9.46s/update, loss=0.726, update=1008]
# Epoch 4/20:  34% 103/302 [12:34<31:22,  9.46s/update, loss=0.626, update=1009]
# Epoch 4/20:  34% 104/302 [12:38<25:27,  7.72s/update, loss=0.626, update=1009]
# Epoch 4/20:  34% 104/302 [12:38<25:27,  7.72s/update, loss=1.21, update=1010]
# Epoch 4/20:  35% 105/302 [12:42<22:15,  6.78s/update, loss=1.21, update=1010]
# Epoch 4/20:  35% 105/302 [12:42<22:15,  6.78s/update, loss=0.671, update=1011]
# Epoch 4/20:  35% 106/302 [12:46<19:26,  5.95s/update, loss=0.671, update=1011]
# Epoch 4/20:  35% 106/302 [12:46<19:26,  5.95s/update, loss=0.778, update=1012]
# Epoch 4/20:  35% 107/302 [12:50<16:49,  5.18s/update, loss=0.778, update=1012]
# Epoch 4/20:  35% 107/302 [12:50<16:49,  5.18s/update, loss=0.549, update=1013]
# Epoch 4/20:  36% 108/302 [12:53<14:48,  4.58s/update, loss=0.549, update=1013]
# Epoch 4/20:  36% 108/302 [12:53<14:48,  4.58s/update, loss=0.732, update=1014]
# Epoch 4/20:  36% 109/302 [12:56<13:41,  4.26s/update, loss=0.732, update=1014]
# Epoch 4/20:  36% 109/302 [12:56<13:41,  4.26s/update, loss=0.802, update=1015]
# Epoch 4/20:  36% 110/302 [13:01<13:42,  4.28s/update, loss=0.802, update=1015]
# Epoch 4/20:  36% 110/302 [13:01<13:42,  4.28s/update, loss=0.655, update=1016]
# Epoch 4/20:  37% 111/302 [13:04<12:55,  4.06s/update, loss=0.655, update=1016]
# Epoch 4/20:  37% 111/302 [13:04<12:55,  4.06s/update, loss=0.778, update=1017]
# Epoch 4/20:  37% 112/302 [13:08<12:38,  3.99s/update, loss=0.778, update=1017]
# Epoch 4/20:  37% 112/302 [13:08<12:38,  3.99s/update, loss=0.737, update=1018]
# Epoch 4/20:  37% 113/302 [13:12<12:57,  4.11s/update, loss=0.737, update=1018]
# Epoch 4/20:  37% 113/302 [13:12<12:57,  4.11s/update, loss=0.725, update=1019]
# Epoch 4/20:  38% 114/302 [13:17<13:19,  4.25s/update, loss=0.725, update=1019]
# Epoch 4/20:  38% 114/302 [13:17<13:19,  4.25s/update, loss=0.733, update=1020]
# Epoch 4/20:  38% 115/302 [13:21<13:20,  4.28s/update, loss=0.733, update=1020]
# Epoch 4/20:  38% 115/302 [13:21<13:20,  4.28s/update, loss=0.588, update=1021]
# Epoch 4/20:  38% 116/302 [13:26<13:23,  4.32s/update, loss=0.588, update=1021]
# Epoch 4/20:  38% 116/302 [13:26<13:23,  4.32s/update, loss=0.761, update=1022]
# Epoch 4/20:  39% 117/302 [13:30<13:26,  4.36s/update, loss=0.761, update=1022]
# Epoch 4/20:  39% 117/302 [13:30<13:26,  4.36s/update, loss=0.555, update=1023]
# Epoch 4/20:  39% 118/302 [13:35<13:19,  4.34s/update, loss=0.555, update=1023]
# Epoch 4/20:  39% 118/302 [13:35<13:19,  4.34s/update, loss=0.765, update=1024]
# Epoch 4/20:  39% 119/302 [13:39<13:27,  4.41s/update, loss=0.765, update=1024]
# Epoch 4/20:  39% 119/302 [13:39<13:27,  4.41s/update, loss=0.67, update=1025]
# Epoch 4/20:  40% 120/302 [13:45<14:23,  4.74s/update, loss=0.67, update=1025]
# Epoch 4/20:  40% 120/302 [13:45<14:23,  4.74s/update, loss=0.585, update=1026]
# Epoch 4/20:  40% 121/302 [13:49<14:18,  4.74s/update, loss=0.585, update=1026]
# Epoch 4/20:  40% 121/302 [13:49<14:18,  4.74s/update, loss=0.797, update=1027]
# Epoch 4/20:  40% 122/302 [13:53<13:34,  4.52s/update, loss=0.797, update=1027]
# Epoch 4/20:  40% 122/302 [13:53<13:34,  4.52s/update, loss=1.76, update=1028]
# Epoch 4/20:  41% 123/302 [13:58<13:11,  4.42s/update, loss=1.76, update=1028]
# Epoch 4/20:  41% 123/302 [13:58<13:11,  4.42s/update, loss=1.05, update=1029]
# Epoch 4/20:  41% 124/302 [14:02<12:56,  4.36s/update, loss=1.05, update=1029]
# Epoch 4/20:  41% 124/302 [14:02<12:56,  4.36s/update, loss=0.594, update=1030]
# Epoch 4/20:  41% 125/302 [14:06<12:46,  4.33s/update, loss=0.594, update=1030]
# Epoch 4/20:  41% 125/302 [14:06<12:46,  4.33s/update, loss=0.728, update=1031]
# Epoch 4/20:  42% 126/302 [14:11<13:24,  4.57s/update, loss=0.728, update=1031]
# Epoch 4/20:  42% 126/302 [14:11<13:24,  4.57s/update, loss=0.921, update=1032]
# Epoch 4/20:  42% 127/302 [14:16<13:58,  4.79s/update, loss=0.921, update=1032]
# Epoch 4/20:  42% 127/302 [14:16<13:58,  4.79s/update, loss=0.611, update=1033]
# Epoch 4/20:  42% 128/302 [14:21<13:53,  4.79s/update, loss=0.611, update=1033]
# Epoch 4/20:  42% 128/302 [14:21<13:53,  4.79s/update, loss=0.693, update=1034]
# Epoch 4/20:  43% 129/302 [14:26<13:29,  4.68s/update, loss=0.693, update=1034]
# Epoch 4/20:  43% 129/302 [14:26<13:29,  4.68s/update, loss=0.73, update=1035]
# Epoch 4/20:  43% 130/302 [14:30<13:05,  4.57s/update, loss=0.73, update=1035]
# Epoch 4/20:  43% 130/302 [14:30<13:05,  4.57s/update, loss=1.07, update=1036]
# Epoch 4/20:  43% 131/302 [14:34<12:22,  4.34s/update, loss=1.07, update=1036]
# Epoch 4/20:  43% 131/302 [14:34<12:22,  4.34s/update, loss=0.662, update=1037]
# Epoch 4/20:  44% 132/302 [14:38<12:26,  4.39s/update, loss=0.662, update=1037]
# Epoch 4/20:  44% 132/302 [14:38<12:26,  4.39s/update, loss=0.624, update=1038]
# Epoch 4/20:  44% 133/302 [14:43<12:36,  4.48s/update, loss=0.624, update=1038]
# Epoch 4/20:  44% 133/302 [14:43<12:36,  4.48s/update, loss=0.652, update=1039]
# Epoch 4/20:  44% 134/302 [14:46<11:37,  4.15s/update, loss=0.652, update=1039]
# Epoch 4/20:  44% 134/302 [14:46<11:37,  4.15s/update, loss=0.661, update=1040]
# Epoch 4/20:  45% 135/302 [14:50<10:53,  3.92s/update, loss=0.661, update=1040]
# Epoch 4/20:  45% 135/302 [14:50<10:53,  3.92s/update, loss=0.722, update=1041]
# Epoch 4/20:  45% 136/302 [14:53<10:33,  3.82s/update, loss=0.722, update=1041]
# Epoch 4/20:  45% 136/302 [14:53<10:33,  3.82s/update, loss=0.749, update=1042]
# Epoch 4/20:  45% 137/302 [14:58<11:10,  4.06s/update, loss=0.749, update=1042]
# Epoch 4/20:  45% 137/302 [14:58<11:10,  4.06s/update, loss=0.659, update=1043]
# Epoch 4/20:  46% 138/302 [15:03<11:32,  4.22s/update, loss=0.659, update=1043]
# Epoch 4/20:  46% 138/302 [15:03<11:32,  4.22s/update, loss=0.69, update=1044]
# Epoch 4/20:  46% 139/302 [15:07<11:33,  4.25s/update, loss=0.69, update=1044]
# Epoch 4/20:  46% 139/302 [15:07<11:33,  4.25s/update, loss=1.27, update=1045]
# Epoch 4/20:  46% 140/302 [15:12<12:21,  4.58s/update, loss=1.27, update=1045]
# Epoch 4/20:  46% 140/302 [15:12<12:21,  4.58s/update, loss=0.881, update=1046]
# Epoch 4/20:  47% 141/302 [15:18<13:01,  4.85s/update, loss=0.881, update=1046]
# Epoch 4/20:  47% 141/302 [15:18<13:01,  4.85s/update, loss=1.02, update=1047]
# Epoch 4/20:  47% 142/302 [15:22<12:40,  4.75s/update, loss=1.02, update=1047]
# Epoch 4/20:  47% 142/302 [15:22<12:40,  4.75s/update, loss=0.796, update=1048]
# Epoch 4/20:  47% 143/302 [15:26<11:58,  4.52s/update, loss=0.796, update=1048]
# Epoch 4/20:  47% 143/302 [15:26<11:58,  4.52s/update, loss=0.915, update=1049]
# Epoch 4/20:  48% 144/302 [15:31<11:54,  4.52s/update, loss=0.915, update=1049]
# Epoch 4/20:  48% 144/302 [15:31<11:54,  4.52s/update, loss=0.593, update=1050]
# Epoch 4/20:  48% 145/302 [15:35<11:33,  4.42s/update, loss=0.593, update=1050]
# Epoch 4/20:  48% 145/302 [15:35<11:33,  4.42s/update, loss=0.745, update=1051]
# Epoch 4/20:  48% 146/302 [15:39<11:17,  4.34s/update, loss=0.745, update=1051]
# Epoch 4/20:  48% 146/302 [15:39<11:17,  4.34s/update, loss=0.759, update=1052]
# Epoch 4/20:  49% 147/302 [15:44<11:24,  4.42s/update, loss=0.759, update=1052]
# Epoch 4/20:  49% 147/302 [15:44<11:24,  4.42s/update, loss=0.574, update=1053]
# Epoch 4/20:  49% 148/302 [15:48<11:08,  4.34s/update, loss=0.574, update=1053]
# Epoch 4/20:  49% 148/302 [15:48<11:08,  4.34s/update, loss=1.43, update=1054]
# Epoch 4/20:  49% 149/302 [15:52<11:14,  4.41s/update, loss=1.43, update=1054]
# Epoch 4/20:  49% 149/302 [15:52<11:14,  4.41s/update, loss=0.742, update=1055]
# Epoch 4/20:  50% 150/302 [15:57<11:35,  4.58s/update, loss=0.742, update=1055]
# Epoch 4/20:  50% 150/302 [15:57<11:35,  4.58s/update, loss=0.708, update=1056]
# Epoch 4/20:  50% 151/302 [16:01<10:58,  4.36s/update, loss=0.708, update=1056]
# Epoch 4/20:  50% 151/302 [16:01<10:58,  4.36s/update, loss=0.638, update=1057]
# Epoch 4/20:  50% 152/302 [16:05<10:49,  4.33s/update, loss=0.638, update=1057]
# Epoch 4/20:  50% 152/302 [16:05<10:49,  4.33s/update, loss=0.944, update=1058]
# Epoch 4/20:  51% 153/302 [16:11<11:22,  4.58s/update, loss=0.944, update=1058]
# Epoch 4/20:  51% 153/302 [16:11<11:22,  4.58s/update, loss=0.8, update=1059]
# Epoch 4/20:  51% 154/302 [16:15<11:03,  4.49s/update, loss=0.8, update=1059]
# Epoch 4/20:  51% 154/302 [16:15<11:03,  4.49s/update, loss=0.732, update=1060]
# Epoch 4/20:  51% 155/302 [16:20<11:03,  4.52s/update, loss=0.732, update=1060]
# Epoch 4/20:  51% 155/302 [16:20<11:03,  4.52s/update, loss=0.816, update=1061]
# Epoch 4/20:  52% 156/302 [16:25<11:39,  4.79s/update, loss=0.816, update=1061]
# Epoch 4/20:  52% 156/302 [16:25<11:39,  4.79s/update, loss=0.867, update=1062]
# Epoch 4/20:  52% 157/302 [16:29<11:02,  4.57s/update, loss=0.867, update=1062]
# Epoch 4/20:  52% 157/302 [16:29<11:02,  4.57s/update, loss=0.628, update=1063]
# Epoch 4/20:  52% 158/302 [16:34<10:57,  4.57s/update, loss=0.628, update=1063]
# Epoch 4/20:  52% 158/302 [16:34<10:57,  4.57s/update, loss=0.769, update=1064]
# Epoch 4/20:  53% 159/302 [16:38<10:41,  4.49s/update, loss=0.769, update=1064]
# Epoch 4/20:  53% 159/302 [16:38<10:41,  4.49s/update, loss=0.928, update=1065]
# Epoch 4/20:  53% 160/302 [16:43<11:06,  4.70s/update, loss=0.928, update=1065]
# Epoch 4/20:  53% 160/302 [16:43<11:06,  4.70s/update, loss=0.82, update=1066]

# %%
# @title
# %cd /content/F5-TTS

# !python src/f5_tts/train/finetune_cli.py \
    --exp_name F5TTS_Base \
    --dataset_name urdu_cv \
    --learning_rate 7.5e-5 \
    --batch_size_per_gpu 2 \
    --batch_size_type frame \
    --max_samples 32 \
    --grad_accumulation_steps 2 \
    --max_grad_norm 1.0 \
    --epochs 20 \
    --num_warmup_updates 1000 \
    --save_per_updates 500 \
    --last_per_updates 250 \
    --finetune \
    --tokenizer char \
    --log_samples \
    --logger tensorboard
# Out:
# /content/F5-TTS
#
# vocab :  2545
#
# vocoder :  vocos
# 2025-10-07 21:59:05.169925: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759874345.189798   22334 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759874345.195946   22334 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759874345.212065   22334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759874345.212094   22334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759874345.212099   22334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759874345.212104   22334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-07 21:59:05.216897: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using logger: tensorboard
# Gradient accumulation checkpointing with per_updates now, old logic per_steps used with before f992c4e
# Loading dataset ...
# Download Vocos from huggingface charactr/vocos-mel-24khz
# Sorting with sampler... if slow, check whether dataset is provided with duration: 100% 4830/4830 [00:00<00:00, 2203926.06it/s]
# Creating dynamic batches with 2 audio frames per gpu: 100% 4830/4830 [00:00<00:00, 2553054.61it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/F5-TTS/src/f5_tts/train/finetune_cli.py", line 214, in <module>
#     main()
#   File "/content/F5-TTS/src/f5_tts/train/finetune_cli.py", line 207, in main
#     trainer.train(
#   File "/content/F5-TTS/src/f5_tts/model/trainer.py", line 333, in train
#     skipped_epoch = int(start_step // orig_epoch_step)
#                         ~~~~~~~~~~~^^~~~~~~~~~~~~~~~~
# ZeroDivisionError: integer division or modulo by zero

# %%
# @title
"""
Complete F5-TTS Dataset Preparation
Creates all required files: vocab.txt, preprocessed data, etc.
"""

import os
import json
import pandas as pd
from pathlib import Path
from collections import Counter
import librosa
import soundfile as sf
from tqdm import tqdm

print("=" * 70)
print("Complete F5-TTS Dataset Preparation for Urdu")
print("=" * 70)

# ============================================
# Configuration
# ============================================
DATASET_DIR = "/content/f5_tts_dataset"
TRAIN_METADATA = f"{DATASET_DIR}/train_metadata.csv"
VAL_METADATA = f"{DATASET_DIR}/val_metadata.csv"

F5_DATA_DIR = "/content/F5-TTS/data/urdu_cv"
os.makedirs(F5_DATA_DIR, exist_ok=True)
os.makedirs(f"{F5_DATA_DIR}/wavs", exist_ok=True)

print(f"\n[1/5] Loading metadata...")
train_df = pd.read_csv(TRAIN_METADATA)
val_df = pd.read_csv(VAL_METADATA)
print(f"   Train samples: {len(train_df)}")
print(f"   Val samples: {len(val_df)}")

# ============================================
# Step 1: Create vocab.txt (Character vocabulary)
# ============================================
print(f"\n[2/5] Creating vocab.txt...")

# Collect all unique characters from transcriptions
all_chars = set()
for text in train_df['text']:
    all_chars.update(text)
for text in val_df['text']:
    all_chars.update(text)

# Sort characters
vocab = sorted(list(all_chars))

# Add special tokens
special_tokens = ['<pad>', '<unk>', '<bos>', '<eos>']
vocab = special_tokens + vocab

# Save vocab.txt
vocab_path = f"{F5_DATA_DIR}/vocab.txt"
with open(vocab_path, 'w', encoding='utf-8') as f:
    for char in vocab:
        f.write(f"{char}\n")

print(f"   ✓ Created vocab.txt with {len(vocab)} characters")
print(f"   Path: {vocab_path}")
print(f"   Sample vocab: {vocab[:20]}")

# ============================================
# Step 2: Create metadata.list with audio info
# ============================================
print(f"\n[3/5] Creating metadata.list with audio information...")

def get_audio_info(audio_path):
    """Get audio duration and sample rate"""
    try:
        info = sf.info(audio_path)
        return info.duration, info.samplerate
    except:
        return 0, 0

metadata_list = []
durations = []

print("   Processing training data...")
for idx, row in tqdm(train_df.iterrows(), total=len(train_df), desc="   Train"):
    audio_src = os.path.join(DATASET_DIR, row['audio_path'])

    if not os.path.exists(audio_src):
        continue

    # Get audio info
    duration, sr = get_audio_info(audio_src)
    if duration == 0:
        continue

    durations.append(duration)

    # Create filename
    audio_filename = f"train_{idx:06d}.wav"
    audio_dst = f"{F5_DATA_DIR}/wavs/{audio_filename}"

    # Create symlink or copy
    if not os.path.exists(audio_dst):
        try:
            os.symlink(audio_src, audio_dst)
        except:
            import shutil
            shutil.copy(audio_src, audio_dst)

    # Format: audio_path|text|speaker|duration|sample_rate
    text = row['text'].strip()
    metadata_list.append(f"wavs/{audio_filename}|{text}|urdu_speaker|{duration:.2f}|{sr}")

# Save metadata
metadata_path = f"{F5_DATA_DIR}/metadata.list"
with open(metadata_path, 'w', encoding='utf-8') as f:
    for line in metadata_list:
        f.write(line + '\n')

print(f"   ✓ Created metadata.list with {len(metadata_list)} samples")
print(f"   Total duration: {sum(durations)/3600:.2f} hours")

# ============================================
# Step 3: Create dataset info JSON
# ============================================
print(f"\n[4/5] Creating dataset_info.json...")

dataset_info = {
    "name": "urdu_cv",
    "description": "Urdu Common Voice dataset for F5-TTS",
    "version": "1.0",
    "num_samples": len(metadata_list),
    "total_duration_hours": sum(durations) / 3600,
    "sample_rate": 24000,  # Target sample rate
    "vocab_size": len(vocab),
    "language": "urdu",
    "speakers": ["urdu_speaker"],
    "train_samples": len(train_df),
    "val_samples": len(val_df)
}

info_path = f"{F5_DATA_DIR}/dataset_info.json"
with open(info_path, 'w', encoding='utf-8') as f:
    json.dump(dataset_info, f, indent=2, ensure_ascii=False)

print(f"   ✓ Created dataset_info.json")
print(f"   Dataset info: {dataset_info}")

# ============================================
# Step 4: Create character-to-index mapping
# ============================================
print(f"\n[5/5] Creating char2idx mapping...")

char2idx = {char: idx for idx, char in enumerate(vocab)}
idx2char = {idx: char for char, idx in char2idx.items()}

# Save mappings
char2idx_path = f"{F5_DATA_DIR}/char2idx.json"
idx2char_path = f"{F5_DATA_DIR}/idx2char.json"

with open(char2idx_path, 'w', encoding='utf-8') as f:
    json.dump(char2idx, f, indent=2, ensure_ascii=False)

with open(idx2char_path, 'w', encoding='utf-8') as f:
    json.dump(idx2char, f, indent=2, ensure_ascii=False)

print(f"   ✓ Created character mappings")

# ============================================
# Verification
# ============================================
print("\n" + "=" * 70)
print("VERIFICATION")
print("=" * 70)

required_files = [
    'vocab.txt',
    'metadata.list',
    'dataset_info.json',
    'char2idx.json',
    'idx2char.json'
]

print(f"\nDataset directory: {F5_DATA_DIR}")
print(f"\nRequired files:")
for filename in required_files:
    filepath = os.path.join(F5_DATA_DIR, filename)
    exists = "✓" if os.path.exists(filepath) else "✗"
    size = os.path.getsize(filepath) if os.path.exists(filepath) else 0
    print(f"  {exists} {filename:20s} ({size:>10,} bytes)")

# Check audio files
audio_files = list(Path(f"{F5_DATA_DIR}/wavs").glob("*.wav"))
print(f"\n  ✓ Audio files: {len(audio_files)}")

# Sample metadata
print(f"\n[Sample metadata.list (first 3 lines)]:")
with open(metadata_path, 'r', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if i < 3:
            print(f"  {line.strip()}")

# Sample vocab
print(f"\n[Sample vocab.txt (first 20 chars)]:")
with open(vocab_path, 'r', encoding='utf-8') as f:
    chars = [line.strip() for line in f]
    print(f"  {chars[:20]}")

print("\n" + "=" * 70)
print("✓ DATASET PREPARATION COMPLETE!")
print("=" * 70)
print(f"\nYour dataset is ready at: {F5_DATA_DIR}")
print(f"Total samples: {len(metadata_list)}")
print(f"Vocabulary size: {len(vocab)} characters")
print(f"Total duration: {sum(durations)/3600:.2f} hours")
print("\n✓ You can now start training!")
print("=" * 70)

# Print training command
print("\n" + "=" * 70)
print("START TRAINING WITH THIS COMMAND:")
# Out:
# ======================================================================
# Complete F5-TTS Dataset Preparation for Urdu
# ======================================================================
#
# [1/5] Loading metadata...
#    Train samples: 4830
#    Val samples: 537
#
# [2/5] Creating vocab.txt...
#    ✓ Created vocab.txt with 96 characters
#    Path: /content/F5-TTS/data/urdu_cv/vocab.txt
#    Sample vocab: ['<pad>', '<unk>', '<bos>', '<eos>', ' ', '!', '"', "'", ',', '-', '.', ':', '`', '،', 'ؑ', 'ؓ', 'ؔ', '؛', '؟', 'ء']
#
# [3/5] Creating metadata.list with audio information...
#    Processing training data...
#    Train: 100%|██████████| 4830/4830 [00:01<00:00, 3398.30it/s]
#    ✓ Created metadata.list with 4830 samples
#    Total duration: 5.64 hours
#
# [4/5] Creating dataset_info.json...
#    ✓ Created dataset_info.json
#    Dataset info: {'name': 'urdu_cv', 'description': 'Urdu Common Voice dataset for F5-TTS', 'version': '1.0', 'num_samples': 4830, 'total_duration_hours': 5.64275, 'sample_rate': 24000, 'vocab_size': 96, 'language': 'urdu', 'speakers': ['urdu_speaker'], 'train_samples': 4830, 'val_samples': 537}
#
# [5/5] Creating char2idx mapping...
#    ✓ Created character mappings
#
# ======================================================================
# VERIFICATION
# ======================================================================
#
# Dataset directory: /content/F5-TTS/data/urdu_cv
#
# Required files:
#   ✓ vocab.txt            (       308 bytes)
#   ✓ metadata.list        (   551,563 bytes)
#   ✓ dataset_info.json    (       311 bytes)
#   ✓ char2idx.json        (     1,165 bytes)
#   ✓ idx2char.json        (     1,357 bytes)
#
#   ✓ Audio files: 5367
#
# [Sample metadata.list (first 3 lines)]:
#   wavs/train_000000.wav|میں آپ کو حوالات میں بند کروا دوں گا|urdu_speaker|3.24|48000
#   wavs/train_000001.wav|اٹھارہویں صدی میں قائم ہونے والے کوئٹہ کو آب و ہوا ماحول اور خوبصورتی کی وجہ سے انگریز لٹل لندن کہتے تھے|urdu_speaker|9.11|48000
#   wavs/train_000002.wav|کامن ویلتھ گیمزپاکستانی ریسلر نے کانسی کا تمغہ جیت لیا|urdu_speaker|5.44|48000
#
# [Sample vocab.txt (first 20 chars)]:
#   ['<pad>', '<unk>', '<bos>', '<eos>', '', '!', '"', "'", ',', '-', '.', ':', '`', '،', 'ؑ', 'ؓ', 'ؔ', '؛', '؟', 'ء']
#
# ======================================================================
# ✓ DATASET PREPARATION COMPLETE!
# ======================================================================
#
# Your dataset is ready at: /content/F5-TTS/data/urdu_cv
# Total samples: 4830
# Vocabulary size: 96 characters
# Total duration: 5.64 hours
#
# ✓ You can now start training!
# ======================================================================
#
# ======================================================================
# START TRAINING WITH THIS COMMAND:

# %%
# @title
"""
Prepare Urdu dataset using F5-TTS's official prepare_csv_wavs.py script
This creates all required files: raw.arrow, vocab.txt, duration.json
"""

import os
import pandas as pd
from pathlib import Path
import shutil

print("=" * 70)
print("Preparing Dataset for F5-TTS (Official Method)")
print("=" * 70)

# ============================================
# Step 1: Create CSV in F5-TTS Expected Format
# ============================================
print("\n[1/4] Creating metadata.csv in F5-TTS format...")

# Source dataset
DATASET_DIR = "/content/f5_tts_dataset"
TRAIN_METADATA = f"{DATASET_DIR}/train_metadata.csv"

# Read our metadata
train_df = pd.read_csv(TRAIN_METADATA)
print(f"   Loaded {len(train_df)} training samples")

# Create F5-TTS compatible directory structure
F5_INPUT_DIR = "/content/f5_input_dataset"
os.makedirs(F5_INPUT_DIR, exist_ok=True)
os.makedirs(f"{F5_INPUT_DIR}/wavs", exist_ok=True)

# F5-TTS expects metadata.csv with format: audio_path|text
# First line should be a header (but it gets skipped)
metadata_lines = ["audio_path|text\n"]  # Header

print("   Creating symlinks for audio files...")
for idx, row in train_df.iterrows():
    audio_src = os.path.join(DATASET_DIR, row['audio_path'])

    if not os.path.exists(audio_src):
        continue

    # Create audio filename
    audio_filename = f"{idx:06d}.wav"
    audio_dst = f"{F5_INPUT_DIR}/wavs/{audio_filename}"

    # Create symlink (saves space)
    if not os.path.exists(audio_dst):
        try:
            os.symlink(audio_src, audio_dst)
        except:
            shutil.copy(audio_src, audio_dst)

    # Add to metadata: relative_path|text
    text = row['text'].strip()
    metadata_lines.append(f"wavs/{audio_filename}|{text}\n")

    if (idx + 1) % 500 == 0:
        print(f"   Processed {idx + 1}/{len(train_df)}...")

# Save metadata.csv
metadata_csv_path = f"{F5_INPUT_DIR}/metadata.csv"
with open(metadata_csv_path, 'w', encoding='utf-8') as f:
    f.writelines(metadata_lines)

print(f"   ✓ Created metadata.csv with {len(metadata_lines)-1} samples")
print(f"   ✓ Input directory: {F5_INPUT_DIR}")

# ============================================
# Step 2: Verify Input Format
# ============================================
print("\n[2/4] Verifying input format...")

# Check structure
has_metadata = os.path.exists(f"{F5_INPUT_DIR}/metadata.csv")
has_wavs_dir = os.path.exists(f"{F5_INPUT_DIR}/wavs") and os.path.isdir(f"{F5_INPUT_DIR}/wavs")
audio_count = len(list(Path(f"{F5_INPUT_DIR}/wavs").glob("*.wav")))

print(f"   metadata.csv exists: {'✓' if has_metadata else '✗'}")
print(f"   wavs/ directory exists: {'✓' if has_wavs_dir else '✗'}")
print(f"   Audio files found: {audio_count}")

if has_metadata and has_wavs_dir and audio_count > 0:
    print("   ✓ Input format is correct!")
else:
    print("   ✗ Input format verification failed!")
    exit(1)

# Sample metadata
print(f"\n   Sample metadata.csv (first 3 lines):")
with open(metadata_csv_path, 'r', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if i < 3:
            print(f"     {line.strip()}")

# ============================================
# Step 3: Run Official prepare_csv_wavs.py
# ============================================
print("\n[3/4] Running F5-TTS's prepare_csv_wavs.py script...")
print("   This will create: raw.arrow, vocab.txt, duration.json")
print("   This may take several minutes...")

# Output directory for prepared dataset
F5_OUTPUT_DIR = "/content/F5-TTS/data/urdu_cv"

# Install required package if not present
print("\n   Installing dependencies...")
os.system("pip install pyarrow -q")

# Run the official preparation script
print("\n   Processing dataset...")
# %cd /content/F5-TTS

# Use --workers to speed up processing (adjust based on CPU)
# !python src/f5_tts/train/datasets/prepare_csv_wavs.py \
    {F5_INPUT_DIR} \
    {F5_OUTPUT_DIR} \
    --workers 4

# ============================================
# Step 4: Verify Output
# ============================================
print("\n[4/4] Verifying prepared dataset...")

required_files = {
    'raw.arrow': 'Preprocessed dataset',
    'vocab.txt': 'Character vocabulary',
    'duration.json': 'Audio durations'
}

print(f"\nOutput directory: {F5_OUTPUT_DIR}")
print(f"\nRequired files:")

all_present = True
for filename, description in required_files.items():
    filepath = os.path.join(F5_OUTPUT_DIR, filename)
    exists = os.path.exists(filepath)
    size = os.path.getsize(filepath) if exists else 0
    status = "✓" if exists else "✗"
    print(f"  {status} {filename:20s} - {description:30s} ({size:>10,} bytes)")
    if not exists:
        all_present = False

if all_present:
    print("\n" + "=" * 70)
    print("✓ DATASET PREPARATION COMPLETE!")
    print("=" * 70)

    # Show dataset info
    import json
    with open(f"{F5_OUTPUT_DIR}/duration.json", 'r') as f:
        duration_data = json.load(f)
        total_hours = sum(duration_data['duration']) / 3600

    with open(f"{F5_OUTPUT_DIR}/vocab.txt", 'r', encoding='utf-8') as f:
        vocab_size = len(f.readlines())

    print(f"\nDataset Statistics:")
    print(f"  Total samples: {len(duration_data['duration'])}")
    print(f"  Total duration: {total_hours:.2f} hours")
    print(f"  Vocabulary size: {vocab_size} characters")
    print(f"  Dataset location: {F5_OUTPUT_DIR}")

    print("\n" + "=" * 70)
    print("START TRAINING WITH THIS COMMAND:")
    print("=" * 70)
    print("""
# %cd /content/F5-TTS

# !python src/f5_tts/train/finetune_cli.py \\
    --exp_name F5TTS_Base \\
    --dataset_name urdu_cv \\
    --learning_rate 7.5e-5 \\
    --batch_size_per_gpu 4 \\
    --batch_size_type frame \\
    --max_samples 64 \\
    --grad_accumulation_steps 1 \\
    --max_grad_norm 1.0 \\
    --epochs 50 \\
    --num_warmup_updates 2000 \\
    --save_per_updates 1000 \\
    --last_per_updates 500 \\
    --finetune \\
    --tokenizer char \\
    --log_samples \\
    --logger tensorboard
    """)
    print("=" * 70)

else:
    print("\n✗ Some required files are missing!")
    print("Check the error messages above.")
# Out:
# ======================================================================
# Preparing Dataset for F5-TTS (Official Method)
# ======================================================================
#
# [1/4] Creating metadata.csv in F5-TTS format...
#    Loaded 4830 training samples
#    Creating symlinks for audio files...
#    Processed 500/4830...
#    Processed 1000/4830...
#    Processed 1500/4830...
#    Processed 2000/4830...
#    Processed 2500/4830...
#    Processed 3000/4830...
#    Processed 3500/4830...
#    Processed 4000/4830...
#    Processed 4500/4830...
#    ✓ Created metadata.csv with 4830 samples
#    ✓ Input directory: /content/f5_input_dataset
#
# [2/4] Verifying input format...
#    metadata.csv exists: ✓
#    wavs/ directory exists: ✓
#    Audio files found: 4830
#    ✓ Input format is correct!
#
#    Sample metadata.csv (first 3 lines):
#      audio_path|text
#      wavs/000000.wav|میں آپ کو حوالات میں بند کروا دوں گا
#      wavs/000001.wav|اٹھارہویں صدی میں قائم ہونے والے کوئٹہ کو آب و ہوا ماحول اور خوبصورتی کی وجہ سے انگریز لٹل لندن کہتے تھے
#
# [3/4] Running F5-TTS's prepare_csv_wavs.py script...
#    This will create: raw.arrow, vocab.txt, duration.json
#    This may take several minutes...
#
#    Installing dependencies...
#
#    Processing dataset...
# /content/F5-TTS
#
# Processing 4830 audio files using 4 workers...
# Processing chunk 1/49: 100% 100/100 [00:08<00:00, 12.25it/s]
# Processing chunk 2/49: 100% 100/100 [00:09<00:00, 10.90it/s]
# Processing chunk 3/49: 100% 100/100 [00:09<00:00, 10.81it/s]
# Processing chunk 4/49: 100% 100/100 [00:08<00:00, 11.31it/s]
# Processing chunk 5/49: 100% 100/100 [00:08<00:00, 11.61it/s]
# Processing chunk 6/49: 100% 100/100 [00:09<00:00, 10.83it/s]
# Processing chunk 7/49: 100% 100/100 [00:09<00:00, 10.96it/s]
# Processing chunk 8/49: 100% 100/100 [00:08<00:00, 12.19it/s]
# Processing chunk 9/49: 100% 100/100 [00:09<00:00, 10.78it/s]
# Processing chunk 10/49: 100% 100/100 [00:10<00:00,  9.85it/s]
# Processing chunk 11/49: 100% 100/100 [00:08<00:00, 12.37it/s]
# Processing chunk 12/49: 100% 100/100 [00:09<00:00, 10.95it/s]
# Processing chunk 13/49: 100% 100/100 [00:09<00:00, 10.88it/s]
# Processing chunk 14/49: 100% 100/100 [00:10<00:00,  9.97it/s]
# Processing chunk 15/49: 100% 100/100 [00:08<00:00, 12.08it/s]
# Processing chunk 16/49: 100% 100/100 [00:09<00:00, 10.90it/s]
# Processing chunk 17/49: 100% 100/100 [00:09<00:00, 10.86it/s]
# Processing chunk 18/49: 100% 100/100 [00:08<00:00, 12.50it/s]
# Processing chunk 19/49: 100% 100/100 [00:09<00:00, 10.98it/s]
# Processing chunk 20/49: 100% 100/100 [00:09<00:00, 11.04it/s]
# Processing chunk 21/49: 100% 100/100 [00:08<00:00, 12.27it/s]
# Processing chunk 22/49: 100% 100/100 [00:09<00:00, 10.79it/s]
# Processing chunk 23/49: 100% 100/100 [00:09<00:00, 10.85it/s]
# Processing chunk 24/49: 100% 100/100 [00:08<00:00, 12.22it/s]
# Processing chunk 25/49: 100% 100/100 [00:09<00:00, 10.92it/s]
# Processing chunk 26/49: 100% 100/100 [00:09<00:00, 10.92it/s]
# Processing chunk 27/49: 100% 100/100 [00:08<00:00, 12.24it/s]
# Processing chunk 28/49: 100% 100/100 [00:09<00:00, 10.94it/s]
# Processing chunk 29/49: 100% 100/100 [00:09<00:00, 10.88it/s]
# Processing chunk 30/49: 100% 100/100 [00:08<00:00, 11.80it/s]
# Processing chunk 31/49: 100% 100/100 [00:08<00:00, 11.33it/s]
# Processing chunk 32/49: 100% 100/100 [00:09<00:00, 10.90it/s]
# Processing chunk 33/49: 100% 100/100 [00:10<00:00,  9.77it/s]
# Processing chunk 34/49: 100% 100/100 [00:08<00:00, 12.28it/s]
# Processing chunk 35/49: 100% 100/100 [00:09<00:00, 10.98it/s]
# Processing chunk 36/49: 100% 100/100 [00:09<00:00, 10.91it/s]
# Processing chunk 37/49: 100% 100/100 [00:08<00:00, 11.31it/s]
# Processing chunk 38/49: 100% 100/100 [00:09<00:00, 10.46it/s]
# Processing chunk 39/49: 100% 100/100 [00:09<00:00, 10.85it/s]
# Processing chunk 40/49: 100% 100/100 [00:08<00:00, 12.02it/s]
# Processing chunk 41/49: 100% 100/100 [00:09<00:00, 11.06it/s]
# Processing chunk 42/49: 100% 100/100 [00:09<00:00, 10.95it/s]
# Processing chunk 43/49: 100% 100/100 [00:08<00:00, 11.53it/s]
# Processing chunk 44/49: 100% 100/100 [00:08<00:00, 11.79it/s]
# Processing chunk 45/49: 100% 100/100 [00:09<00:00, 10.82it/s]
# Processing chunk 46/49: 100% 100/100 [00:09<00:00, 10.93it/s]
# Processing chunk 47/49: 100% 100/100 [00:08<00:00, 12.25it/s]
# Processing chunk 48/49: 100% 100/100 [00:09<00:00, 10.83it/s]
# Processing chunk 49/49: 100% 30/30 [00:02<00:00, 12.08it/s]
#
# Saving to /content/F5-TTS/data/urdu_cv ...
# Writing to raw.arrow ...: 100% 4830/4830 [00:00<00:00, 172013.01it/s]
#
# For urdu_cv, sample count: 4830
# For urdu_cv, vocab size is: 87
# For urdu_cv, total 5.64 hours
#
# [4/4] Verifying prepared dataset...
#
# Output directory: /content/F5-TTS/data/urdu_cv
#
# Required files:
#   ✓ raw.arrow            - Preprocessed dataset           ( 1,321,720 bytes)
#   ✓ vocab.txt            - Character vocabulary           (    13,800 bytes)
#   ✓ duration.json        - Audio durations                (    31,994 bytes)
#
# ======================================================================
# ✓ DATASET PREPARATION COMPLETE!
# ======================================================================
#
# Dataset Statistics:
#   Total samples: 4830
#   Total duration: 5.64 hours
#   Vocabulary size: 2545 characters
#   Dataset location: /content/F5-TTS/data/urdu_cv
#
# ======================================================================
# START TRAINING WITH THIS COMMAND:
# ======================================================================
#
# %cd /content/F5-TTS
#
# !python src/f5_tts/train/finetune_cli.py \
#     --exp_name F5TTS_Base \
#     --dataset_name urdu_cv \
#     --learning_rate 7.5e-5 \
#     --batch_size_per_gpu 4 \
#     --batch_size_type frame \
#     --max_samples 64 \
#     --grad_accumulation_steps 1 \
#     --max_grad_norm 1.0 \
#     --epochs 50 \
#     --num_warmup_updates 2000 \
#     --save_per_updates 1000 \
#     --last_per_updates 500 \
#     --finetune \
#     --tokenizer char \
#     --log_samples \
#     --logger tensorboard
#
# ======================================================================

# %%
# @title
# Let's check what the training script actually loads
# %cd /content/F5-TTS
# !grep -r "arrow" src/f5_tts/train/ --include="*.py"
# !grep -r "load_dataset" src/f5_tts/train/ --include="*.py"
# !grep -r "Dataset" src/f5_tts/train/finetune_cli.py | head -20
# Out:
# /content/F5-TTS
# src/f5_tts/train/finetune_gradio.py:from datasets.arrow_writer import ArrowWriter
# src/f5_tts/train/finetune_gradio.py:    file_raw = os.path.join(path_project, "raw.arrow")
# src/f5_tts/train/finetune_gradio.py:    file_raw = os.path.join(path_project, "raw.arrow")
# src/f5_tts/train/finetune_gradio.py:        f"prepare complete \nsamples : {len(text_list)}\ntime data : {format_seconds_to_hms(lenght)}\nmin sec : {min_second}\nmax sec : {max_second}\nfile_arrow : {file_raw}\nvocab : {vocab_size}\n{error_text}",
# src/f5_tts/train/finetune_gradio.py:    file_arrow = os.path.join(path_project, "raw.arrow")
# src/f5_tts/train/finetune_gradio.py:    if not os.path.isfile(file_arrow):
# src/f5_tts/train/finetune_gradio.py:    dataset = Dataset_.from_file(file_arrow)
# src/f5_tts/train/finetune_gradio.py:Skip this step if you have your dataset, raw.arrow, duration.json, and vocab.txt
# src/f5_tts/train/datasets/prepare_wenetspeech4tts.py:    dataset.save_to_disk(f"{save_dir}/raw", max_shard_size="2GB")  # arrow format
# src/f5_tts/train/datasets/prepare_emilia.py:from datasets.arrow_writer import ArrowWriter
# src/f5_tts/train/datasets/prepare_emilia.py:    with ArrowWriter(path=f"{save_dir}/raw.arrow") as writer:
# src/f5_tts/train/datasets/prepare_emilia.py:        for line in tqdm(result, desc="Writing to raw.arrow ..."):
# src/f5_tts/train/datasets/prepare_ljspeech.py:from datasets.arrow_writer import ArrowWriter
# src/f5_tts/train/datasets/prepare_ljspeech.py:    with ArrowWriter(path=f"{save_dir}/raw.arrow") as writer:
# src/f5_tts/train/datasets/prepare_ljspeech.py:        for line in tqdm(result, desc="Writing to raw.arrow ..."):
# src/f5_tts/train/datasets/prepare_libritts.py:from datasets.arrow_writer import ArrowWriter
# src/f5_tts/train/datasets/prepare_libritts.py:    with ArrowWriter(path=f"{save_dir}/raw.arrow") as writer:
# src/f5_tts/train/datasets/prepare_libritts.py:        for line in tqdm(result, desc="Writing to raw.arrow ..."):
# src/f5_tts/train/datasets/prepare_csv_wavs.py:from datasets.arrow_writer import ArrowWriter
# src/f5_tts/train/datasets/prepare_csv_wavs.py:    raw_arrow_path = out_dir / "raw.arrow"
# src/f5_tts/train/datasets/prepare_csv_wavs.py:    with ArrowWriter(path=raw_arrow_path.as_posix()) as writer:
# src/f5_tts/train/datasets/prepare_csv_wavs.py:        for line in tqdm(result, desc="Writing to raw.arrow ..."):
# src/f5_tts/train/datasets/prepare_emilia_v2.py:from datasets.arrow_writer import ArrowWriter
# src/f5_tts/train/datasets/prepare_emilia_v2.py:    with ArrowWriter(path=f"{save_dir}/raw.arrow") as writer:
# src/f5_tts/train/datasets/prepare_emilia_v2.py:        for line in tqdm(result, desc="Writing to raw.arrow ..."):
# src/f5_tts/train/train.py:from f5_tts.model.dataset import load_dataset
# src/f5_tts/train/train.py:    train_dataset = load_dataset(model_cfg.datasets.name, tokenizer, mel_spec_kwargs=model_cfg.model.mel_spec)
# src/f5_tts/train/finetune_cli.py:from f5_tts.model.dataset import load_dataset
# src/f5_tts/train/finetune_cli.py:    train_dataset = load_dataset(args.dataset_name, tokenizer, mel_spec_kwargs=mel_spec_kwargs)
# # -------------------------- Dataset Settings --------------------------- #

# %%
# @title
# Look at the dataset loading code
# !cat src/f5_tts/train/finetune_cli.py | grep -A 30 "def load"

# %%
# @title
# Check the prepare scripts
# !ls -la src/f5_tts/train/datasets/
# !cat src/f5_tts/train/datasets/prepare_csv_wavs.py
# Out:
# total 48
# drwxr-xr-x 2 root root  4096 Oct  7 21:11 .
# drwxr-xr-x 3 root root  4096 Oct  7 21:11 ..
# -rw-r--r-- 1 root root 10526 Oct  7 21:11 prepare_csv_wavs.py
# -rw-r--r-- 1 root root  7430 Oct  7 21:11 prepare_emilia.py
# -rw-r--r-- 1 root root  3245 Oct  7 21:11 prepare_emilia_v2.py
# -rw-r--r-- 1 root root  3181 Oct  7 21:11 prepare_libritts.py
# -rw-r--r-- 1 root root  2276 Oct  7 21:11 prepare_ljspeech.py
# -rw-r--r-- 1 root root  4580 Oct  7 21:11 prepare_wenetspeech4tts.py
# import concurrent.futures
# import multiprocessing
# import os
# import shutil
# import signal
# import subprocess  # For invoking ffprobe
# import sys
# from contextlib import contextmanager
#
#
# sys.path.append(os.getcwd())
#
# import argparse
# import csv
# import json
# from importlib.resources import files
# from pathlib import Path
#
# import torchaudio
# from datasets.arrow_writer import ArrowWriter
# from tqdm import tqdm
#
# from f5_tts.model.utils import convert_char_to_pinyin
#
#
# PRETRAINED_VOCAB_PATH = files("f5_tts").joinpath("../../data/Emilia_ZH_EN_pinyin/vocab.txt")
#
#
# def is_csv_wavs_format(input_dataset_dir):
#     fpath = Path(input_dataset_dir)
#     metadata = fpath / "metadata.csv"
#     wavs = fpath / "wavs"
#     return metadata.exists() and metadata.is_file() and wavs.exists() and wavs.is_dir()
#
#
# # Configuration constants
# BATCH_SIZE = 100  # Batch size for text conversion
# MAX_WORKERS = max(1, multiprocessing.cpu_count() - 1)  # Leave one CPU free
# THREAD_NAME_PREFIX = "AudioProcessor"
# CHUNK_SIZE = 100  # Number of files to process per worker batch
#
# executor = None  # Global executor for cleanup
#
#
# @contextmanager
# def graceful_exit():
#     """Context manager for graceful shutdown on signals"""
#
#     def signal_handler(signum, frame):
#         print("\nReceived signal to terminate. Cleaning up...")
#         if executor is not None:
#             print("Shutting down executor...")
#             executor.shutdown(wait=False, cancel_futures=True)
#         sys.exit(1)
#
#     # Set up signal handlers
#     signal.signal(signal.SIGINT, signal_handler)
#     signal.signal(signal.SIGTERM, signal_handler)
#
#     try:
#         yield
#     finally:
#         if executor is not None:
#             executor.shutdown(wait=False)
#
#
# def process_audio_file(audio_path, text, polyphone):
#     """Process a single audio file by checking its existence and extracting duration."""
#     if not Path(audio_path).exists():
#         print(f"audio {audio_path} not found, skipping")
#         return None
#     try:
#         audio_duration = get_audio_duration(audio_path)
#         if audio_duration <= 0:
#             raise ValueError(f"Duration {audio_duration} is non-positive.")
#         return (audio_path, text, audio_duration)
#     except Exception as e:
#         print(f"Warning: Failed to process {audio_path} due to error: {e}. Skipping corrupt file.")
#         return None
#
#
# def batch_convert_texts(texts, polyphone, batch_size=BATCH_SIZE):
#     """Convert a list of texts to pinyin in batches."""
#     converted_texts = []
#     for i in range(0, len(texts), batch_size):
#         batch = texts[i : i + batch_size]
#         converted_batch = convert_char_to_pinyin(batch, polyphone=polyphone)
#         converted_texts.extend(converted_batch)
#     return converted_texts
#
#
# def prepare_csv_wavs_dir(input_dir, num_workers=None):
#     global executor
#     assert is_csv_wavs_format(input_dir), f"not csv_wavs format: {input_dir}"
#     input_dir = Path(input_dir)
#     metadata_path = input_dir / "metadata.csv"
#     audio_path_text_pairs = read_audio_text_pairs(metadata_path.as_posix())
#
#     polyphone = True
#     total_files = len(audio_path_text_pairs)
#
#     # Use provided worker count or calculate optimal number
#     worker_count = num_workers if num_workers is not None else min(MAX_WORKERS, total_files)
#     print(f"\nProcessing {total_files} audio files using {worker_count} workers...")
#
#     with graceful_exit():
#         # Initialize thread pool with optimized settings
#         with concurrent.futures.ThreadPoolExecutor(
#             max_workers=worker_count, thread_name_prefix=THREAD_NAME_PREFIX
#         ) as exec:
#             executor = exec
#             results = []
#
#             # Process files in chunks for better efficiency
#             for i in range(0, len(audio_path_text_pairs), CHUNK_SIZE):
#                 chunk = audio_path_text_pairs[i : i + CHUNK_SIZE]
#                 # Submit futures in order
#                 chunk_futures = [executor.submit(process_audio_file, pair[0], pair[1], polyphone) for pair in chunk]
#
#                 # Iterate over futures in the original submission order to preserve ordering
#                 for future in tqdm(
#                     chunk_futures,
#                     total=len(chunk),
#                     desc=f"Processing chunk {i // CHUNK_SIZE + 1}/{(total_files + CHUNK_SIZE - 1) // CHUNK_SIZE}",
#                 ):
#                     try:
#                         result = future.result()
#                         if result is not None:
#                             results.append(result)
#                     except Exception as e:
#                         print(f"Error processing file: {e}")
#
#             executor = None
#
#     # Filter out failed results
#     processed = [res for res in results if res is not None]
#     if not processed:
#         raise RuntimeError("No valid audio files were processed!")
#
#     # Batch process text conversion
#     raw_texts = [item[1] for item in processed]
#     converted_texts = batch_convert_texts(raw_texts, polyphone, batch_size=BATCH_SIZE)
#
#     # Prepare final results
#     sub_result = []
#     durations = []
#     vocab_set = set()
#
#     for (audio_path, _, duration), conv_text in zip(processed, converted_texts):
#         sub_result.append({"audio_path": audio_path, "text": conv_text, "duration": duration})
#         durations.append(duration)
#         vocab_set.update(list(conv_text))
#
#     return sub_result, durations, vocab_set
#
#
# def get_audio_duration(audio_path, timeout=5):
#     """
#     Get the duration of an audio file in seconds using ffmpeg's ffprobe.
#     Falls back to torchaudio.load() if ffprobe fails.
#     """
#     try:
#         cmd = [
#             "ffprobe",
#             "-v",
#             "error",
#             "-show_entries",
#             "format=duration",
#             "-of",
#             "default=noprint_wrappers=1:nokey=1",
#             audio_path,
#         ]
#         result = subprocess.run(
#             cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, check=True, timeout=timeout
#         )
#         duration_str = result.stdout.strip()
#         if duration_str:
#             return float(duration_str)
#         raise ValueError("Empty duration string from ffprobe.")
#     except (subprocess.TimeoutExpired, subprocess.SubprocessError, ValueError) as e:
#         print(f"Warning: ffprobe failed for {audio_path} with error: {e}. Falling back to torchaudio.")
#         try:
#             audio, sample_rate = torchaudio.load(audio_path)
#             return audio.shape[1] / sample_rate
#         except Exception as e:
#             raise RuntimeError(f"Both ffprobe and torchaudio failed for {audio_path}: {e}")
#
#
# def read_audio_text_pairs(csv_file_path):
#     audio_text_pairs = []
#
#     parent = Path(csv_file_path).parent
#     with open(csv_file_path, mode="r", newline="", encoding="utf-8-sig") as csvfile:
#         reader = csv.reader(csvfile, delimiter="|")
#         next(reader)  # Skip the header row
#         for row in reader:
#             if len(row) >= 2:
#                 audio_file = row[0].strip()  # First column: audio file path
#                 text = row[1].strip()  # Second column: text
#                 audio_file_path = parent / audio_file
#                 audio_text_pairs.append((audio_file_path.as_posix(), text))
#
#     return audio_text_pairs
#
#
# def save_prepped_dataset(out_dir, result, duration_list, text_vocab_set, is_finetune):
#     out_dir = Path(out_dir)
#     out_dir.mkdir(exist_ok=True, parents=True)
#     print(f"\nSaving to {out_dir} ...")
#
#     raw_arrow_path = out_dir / "raw.arrow"
#     with ArrowWriter(path=raw_arrow_path.as_posix()) as writer:
#         for line in tqdm(result, desc="Writing to raw.arrow ..."):
#             writer.write(line)
#         writer.finalize()
#
#     # Save durations to JSON
#     dur_json_path = out_dir / "duration.json"
#     with open(dur_json_path.as_posix(), "w", encoding="utf-8") as f:
#         json.dump({"duration": duration_list}, f, ensure_ascii=False)
#
#     # Handle vocab file - write only once based on finetune flag
#     voca_out_path = out_dir / "vocab.txt"
#     if is_finetune:
#         file_vocab_finetune = PRETRAINED_VOCAB_PATH.as_posix()
#         shutil.copy2(file_vocab_finetune, voca_out_path)
#     else:
#         with open(voca_out_path.as_posix(), "w") as f:
#             for vocab in sorted(text_vocab_set):
#                 f.write(vocab + "\n")
#
#     dataset_name = out_dir.stem
#     print(f"\nFor {dataset_name}, sample count: {len(result)}")
#     print(f"For {dataset_name}, vocab size is: {len(text_vocab_set)}")
#     print(f"For {dataset_name}, total {sum(duration_list) / 3600:.2f} hours")
#
#
# def prepare_and_save_set(inp_dir, out_dir, is_finetune: bool = True, num_workers: int = None):
#     if is_finetune:
#         assert PRETRAINED_VOCAB_PATH.exists(), f"pretrained vocab.txt not found: {PRETRAINED_VOCAB_PATH}"
#     sub_result, durations, vocab_set = prepare_csv_wavs_dir(inp_dir, num_workers=num_workers)
#     save_prepped_dataset(out_dir, sub_result, durations, vocab_set, is_finetune)
#
#
# def cli():
#     try:
#         # Before processing, check if ffprobe is available.
#         if shutil.which("ffprobe") is None:
#             print(
#                 "Warning: ffprobe is not available. Duration extraction will rely on torchaudio (which may be slower)."
#             )
#
#         # Usage examples in help text
#         parser = argparse.ArgumentParser(
#             description="Prepare and save dataset.",
#             epilog="""
# Examples:
#     # For fine-tuning (default):
#     python prepare_csv_wavs.py /input/dataset/path /output/dataset/path
#
#     # For pre-training:
#     python prepare_csv_wavs.py /input/dataset/path /output/dataset/path --pretrain
#
#     # With custom worker count:
#     python prepare_csv_wavs.py /input/dataset/path /output/dataset/path --workers 4
#             """,
#         )
#         parser.add_argument("inp_dir", type=str, help="Input directory containing the data.")
#         parser.add_argument("out_dir", type=str, help="Output directory to save the prepared data.")
#         parser.add_argument("--pretrain", action="store_true", help="Enable for new pretrain, otherwise is a fine-tune")
#         parser.add_argument("--workers", type=int, help=f"Number of worker threads (default: {MAX_WORKERS})")
#         args = parser.parse_args()
#
#         prepare_and_save_set(args.inp_dir, args.out_dir, is_finetune=not args.pretrain, num_workers=args.workers)
#     except KeyboardInterrupt:
#         print("\nOperation cancelled by user. Cleaning up...")
#         if executor is not None:
#             executor.shutdown(wait=False, cancel_futures=True)
#         sys.exit(1)
#
#
# if __name__ == "__main__":
#     cli()
